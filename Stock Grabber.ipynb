# %% [markdown]
# # Value Investing Automation
#
# ## 1. Load Libraries

# %%
import csv
import requests
import numpy as np
from time import sleep

# %% [markdown]
# ## 2. Set some initial parameters

# %%
# Minimum market capitalization, to weed out small-cap stocks
min_cap = 300000000
# API key required to access teh financial modeling prep services
api_key = 'api key here'

# %% [markdown]
# ## 3. Grab a list of NYSE & NASDAQstock tickers
#
# Grabbed from a generic .csv file containing almost all stocks listed on the NYSE

# %%
stocks_raw = []

# %% [markdown]
# Grab NYSE listed stocks

# %%
ticker_to_name = {}

with open("nyse-listed.csv", mode='r') as csv_file:
    # open the .csv and iterate through the rows
    csv_reader = csv.DictReader(csv_file)
    line = 0
    for row in csv_reader:
        line += 1
        if '$' in row['ACT Symbol']:
            # '$' character is found in some weird listings in the .csv file.
            # Just ignore these listings
            continue
        if line == 0:
            # first (zeroeth) line is just column labels, ignore them
            continue
        
        # put the ticker into a list if it matches the above criteria.
        # Called an 'ACT Symbol' for some reason in this .csv
        stocks_raw.append(row['ACT Symbol'])
        ticker_to_name[row['ACT Symbol']] = row['Company Name']

# %% [markdown]
# Grab NASDAQ listed stocks that aren't found on the NYSE

# %%
with open('nasdaqlisted.txt', mode='r') as txt_file:
    for line in txt_file:
        ticker = line.split("|")[0]
        company_name = line.split("|")[1].split(" - ")[0]
        if ticker == "Symbol":
            continue    # First line is just column labels, ignore it
        if ticker in ticker_to_name:
            continue    # If it's listed also on the NYSE skip it to avoid duplicates
        
        ticker_to_name[ticker] = company_name
        stocks_raw.append(ticker)

# %% [markdown]
# Print the tickers, if requested

# %%
#for ticker in stocks_raw:
#    print(ticker)

# %% [markdown]
# ## 4. Define functions to grab the market capitalization (CAP), return on invested capital (ROIC), and price to earnings ratio (PE)

# %%
key_metrics_dict = {}

# %%
def getCAP(stock, api_key):
    if not stock in key_metrics_dict:
        try:
            # Try to grab the information directly
            key_metrics = requests.get(f"https://financialmodelingprep.com/api/v3/key-metrics/{stock}?limit=1&apikey={api_key}").json()
        except:
            # If attempt fails, it's most likely we've exceeded the number of API calls allowed
            # within a specific amount of time. Wait a few minutes and then try again.
            print("getCAP: too many requests! Pausing for 5 minutes")
            sleep(300)
            key_metrics = requests.get(f"https://financialmodelingprep.com/api/v3/key-metrics/{stock}?limit=1&apikey={api_key}").json()
        key_metrics_dict[stock] = key_metrics
    else:
        key_metrics = key_metrics_dict[stock]
        
    try:
        # try to return the CAP. It is sometimes possible that the CAP is not available
        # for a given ticker. If that is the case, return Nothing
        return key_metrics[0]['marketCap']
    except:
        return None

# ============================= Same logic applies on lower 2 functions ======================================== #
    
def getROIC(stock, api_key):
    if not stock in key_metrics_dict:
        try:
            key_metrics = requests.get(f"https://financialmodelingprep.com/api/v3/key-metrics/{stock}?limit=1&apikey={api_key}").json()
        except:
            print("getROIC: too many requests! Pausing for 5 minutes")
            sleep(300)
            key_metrics = requests.get(f"https://financialmodelingprep.com/api/v3/key-metrics/{stock}?limit=1&apikey={api_key}").json()
        key_metrics_dict[stock] = key_metrics
    else:
        key_metrics = key_metrics_dict[stock]
        
    try:
        return key_metrics[0]['roic']
    except:
        return None
    

def getPE(stock, api_key):
    if not stock in key_metrics_dict:
        try:
            key_metrics = requests.get(f"https://financialmodelingprep.com/api/v3/key-metrics/{stock}?period=annual&limit=1&apikey={api_key}").json()
        except:
            print("getPE: too many requests! Pausing for 5 minutes")
            sleep(300)
            key_metrics = requests.get(f"https://financialmodelingprep.com/api/v3/key-metrics/{stock}?period=annual&limit=1&apikey={api_key}").json()
        key_metrics_dict[stock] = key_metrics
    else:
        key_metrics = key_metrics_dict[stock]
    
    try:
        return key_metrics[0]['peRatio']
    except:
        return None

# Perform some tests to ensure that the above functions work,
# grab some basic information on Apple Inc.
print("(Example) Apple market cap:\t" + str(getCAP('AAPL', api_key)))
print("(Example) Apple ROIC:\t\t" + str(getROIC('AAPL', api_key)))
print("(Example) Apple PE:\t\t" + str(getPE('AAPL', api_key)))
# Out:
# (Example) Apple market cap:	1996361343006.3572
# (Example) Apple ROIC:		0.30705825278265964
# (Example) Apple PE:		34.773150493918536

# %% [markdown]
# ## 5. Remove the tickers with market caps below the pre-specified threshold

# %%
stocks = []
for s in stocks_raw:
    # Grab the market cap for a ticker
    cap = getCAP(s, api_key)
    
    # If the market capitalization cannot be found, don't add it. Just skip it.
    if not cap:
        continue
        
    # If the ticker's market cap is above the threshold, add it.
    if cap >= min_cap:
        stocks.append(s)
# Out:
# getCAP: too many requests! Pausing for 5 minutes

# %% [markdown]
# ## 6. Grab the PE & ROIC for remaining tickers

# %%
stockdat = []
for s in stocks:
    sdat = {}
    roic = getROIC(s, api_key)    # Grab the ROIC
    pe = getPE(s, api_key)        # Grab the PE ratio
    
    # If either the ROIC or PE ratio cannot be found for a
    # ticker, ignore it.
    if (roic is None) or (pe is None):
        continue
        
    # Add the pe, roic, and name to a dictionary object and
    # append it to a list of stock data
    sdat['pe'] = pe
    sdat['roic'] = roic
    sdat['name'] = s
    
    stockdat.append(sdat)

# %% [markdown]
# ## 7. Sort the tickers by general rank
#
# Set some initial parameters to further sort results

# %%
filter_results = True

pe_min = 0.0             # minimum price to earnings ratio
pe_max = 60.0            # maximum price to earnings ratio

roic_min = 0.06          # minimum ROIC
roic_max = 9999999999    # maximum ROIC

# %%
# Generate an argsort list to organize the PE ratios from lowest to highest
pe_list_argsort = np.argsort(np.array([x['pe'] for x in stockdat]))

# Generate an argsort list to organize the ROIC from highest to lowest
roic_list_argsort = np.flip(np.argsort(np.array([x['roic'] for x in stockdat])))

# Attach the PE ratio & ROIC rankings to each ticker.
# Also calculate a "general" rank by adding each PE & ROIC
# ranking.
for i in range(len(stockdat)):
    stockdat[pe_list_argsort[i]]['pe_rank'] = i
    stockdat[roic_list_argsort[i]]['roic_rank'] = i
    
for i in range(len(stockdat)):
    stockdat[i]['rank'] = stockdat[i]['pe_rank'] + stockdat[i]['roic_rank']
    stockdat[i]['Full Name'] = ticker_to_name[stockdat[i]['name']]
    stockdat[i]['Website'] =  f"https://finance.yahoo.com/quote/{stockdat[i]['name']}?p={stockdat[i]['name']}&.tsrc=fin-srch"

# Generate an argsort list to organize stock tickers by "general rank"
rank_argsort = np.argsort(np.array([x['rank'] for x in stockdat]))

#for i in range(10):
    #roic_sorted = sorted(stockdat, key = lambda x: x['roic_rank'])
    #pe_sorted = sorted(stockdat, key = lambda x: x['pe_rank'])
    #print(roic_sorted[i]['roic'], roic_sorted[i]['roic_rank'])
    #print(pe_sorted[i]['pe'], pe_sorted[i]['pe_rank'])
    #print(stockdat[roic_list_argsort[i]]['roic'], stockdat[roic_list_argsort[i]]['roic_rank'])
    
    
# Print all stock tickers in order of "general" rank, assuming
# they're within the thresholds
print("Name \t|\t rank \t|\t PE \t|\t ROIC \t|\t Website")
print("=====================================================================================================")
for i in range(len(stockdat)):
    sdat = stockdat[rank_argsort[i]]
    
    if(filter_results):
        if (sdat['pe'] <= pe_min) or (sdat['pe'] >= pe_max):
            continue
        if (sdat['roic'] <= roic_min) or (sdat['roic'] >= roic_max):
            continue
    
    
    print(str(sdat['name']) +
          "\t|\t" +
          str(sdat['rank']) +
          "\t|\t" +
          "{0:.3f}".format(sdat['pe']) +
          "x\t|\t" +
          "{0:.2%}".format(sdat['roic']) +
          "\t|\t" +
          ticker_to_name[sdat['name']] + " " +
          f"https://finance.yahoo.com/quote/{sdat['name']}?p={sdat['name']}&.tsrc=fin-srch")
# Out:
# Name 	|	 rank 	|	 PE 	|	 ROIC 	|	 Website
# =====================================================================================================
# XBIT	|	999	|	1.318x	|	94.95%	|	XBiotech Inc. https://finance.yahoo.com/quote/XBIT?p=XBIT&.tsrc=fin-srch
# UZA	|	1015	|	1.591x	|	56.30%	|	United States Cellular Corporation 6.95% Senior Notes due 2060 https://finance.yahoo.com/quote/UZA?p=UZA&.tsrc=fin-srch
# NVO	|	1059	|	3.710x	|	72.87%	|	Novo Nordisk A/S Common Stock https://finance.yahoo.com/quote/NVO?p=NVO&.tsrc=fin-srch
# QFIN	|	1064	|	0.521x	|	27.76%	|	360 DigiTech, Inc. https://finance.yahoo.com/quote/QFIN?p=QFIN&.tsrc=fin-srch
# OMAB	|	1065	|	0.937x	|	28.67%	|	Grupo Aeroportuario del Centro Norte S.A.B. de C.V. https://finance.yahoo.com/quote/OMAB?p=OMAB&.tsrc=fin-srch
# LXRX	|	1071	|	2.612x	|	35.22%	|	Lexicon Pharmaceuticals, Inc. https://finance.yahoo.com/quote/LXRX?p=LXRX&.tsrc=fin-srch
# HHR	|	1075	|	0.739x	|	26.66%	|	HeadHunter Group PLC https://finance.yahoo.com/quote/HHR?p=HHR&.tsrc=fin-srch
# TSM	|	1081	|	1.217x	|	27.28%	|	Taiwan Semiconductor Manufacturing Company Ltd. https://finance.yahoo.com/quote/TSM?p=TSM&.tsrc=fin-srch
# TLK	|	1085	|	0.001x	|	23.52%	|	PT Telekomunikasi Indonesia, Tbk https://finance.yahoo.com/quote/TLK?p=TLK&.tsrc=fin-srch
# BMA	|	1086	|	0.098x	|	24.38%	|	Banco Macro S.A.  ADR (representing Ten Class B Common Shares) https://finance.yahoo.com/quote/BMA?p=BMA&.tsrc=fin-srch
# LX	|	1092	|	2.226x	|	28.69%	|	LexinFintech Holdings Ltd. https://finance.yahoo.com/quote/LX?p=LX&.tsrc=fin-srch
# WUBA	|	1110	|	2.102x	|	26.11%	|	58.com Inc. American Depositary Shares, each representing 2 Class A Ordinary Shares https://finance.yahoo.com/quote/WUBA?p=WUBA&.tsrc=fin-srch
# SIGA	|	1115	|	5.563x	|	52.75%	|	SIGA Technologies Inc. https://finance.yahoo.com/quote/SIGA?p=SIGA&.tsrc=fin-srch
# BST	|	1119	|	3.538x	|	29.47%	|	BlackRock Science and Technology Trust Common Shares of Beneficial Interest https://finance.yahoo.com/quote/BST?p=BST&.tsrc=fin-srch
# WLKP	|	1123	|	2.458x	|	25.95%	|	Westlake Chemical Partners LP Common Units representing limited partner interests https://finance.yahoo.com/quote/WLKP?p=WLKP&.tsrc=fin-srch
# INVA	|	1139	|	5.414x	|	35.66%	|	Innoviva, Inc. https://finance.yahoo.com/quote/INVA?p=INVA&.tsrc=fin-srch
# NIU	|	1164	|	3.383x	|	24.26%	|	Niu Technologies https://finance.yahoo.com/quote/NIU?p=NIU&.tsrc=fin-srch
# QIWI	|	1165	|	0.240x	|	20.42%	|	QIWI plc https://finance.yahoo.com/quote/QIWI?p=QIWI&.tsrc=fin-srch
# NTES	|	1166	|	1.990x	|	22.18%	|	NetEase, Inc. https://finance.yahoo.com/quote/NTES?p=NTES&.tsrc=fin-srch
# ENVA	|	1166	|	1.908x	|	21.98%	|	Enova International, Inc. Common Stock https://finance.yahoo.com/quote/ENVA?p=ENVA&.tsrc=fin-srch
# HLG	|	1176	|	3.440x	|	23.69%	|	Hailiang Education Group Inc. https://finance.yahoo.com/quote/HLG?p=HLG&.tsrc=fin-srch
# SCU	|	1176	|	1.983x	|	21.53%	|	Scana Corporation SCANA CORPORATION 2009 Series A 7.70% Enhanced Junior Subordinated Notes https://finance.yahoo.com/quote/SCU?p=SCU&.tsrc=fin-srch
# VIPS	|	1180	|	0.429x	|	20.05%	|	Vipshop Holdings Limited American Depositary Shares, each representing two ordinary shares https://finance.yahoo.com/quote/VIPS?p=VIPS&.tsrc=fin-srch
# BIO	|	1180	|	6.230x	|	31.83%	|	Bio https://finance.yahoo.com/quote/BIO?p=BIO&.tsrc=fin-srch
# SHLX	|	1199	|	4.871x	|	24.55%	|	Shell Midstream Partners, L.P. Common Units representing Limited Partner Interests https://finance.yahoo.com/quote/SHLX?p=SHLX&.tsrc=fin-srch
# RVT	|	1201	|	3.752x	|	22.65%	|	Royce Value Trust, Inc. Common Stock https://finance.yahoo.com/quote/RVT?p=RVT&.tsrc=fin-srch
# PAC	|	1203	|	1.325x	|	19.91%	|	Grupo Aeroportuario Del Pacifico, S.A. B. de C.V. Grupo Aeroportuario Del Pacifico, S.A. de C.V. (each representing 10 Series B shares) https://finance.yahoo.com/quote/PAC?p=PAC&.tsrc=fin-srch
# VIOT	|	1215	|	5.393x	|	24.40%	|	Viomi Technology Co., Ltd https://finance.yahoo.com/quote/VIOT?p=VIOT&.tsrc=fin-srch
# FENG	|	1219	|	1.536x	|	19.48%	|	Phoenix New Media Limited American Depositary Shares, each representing 8 Class A ordinary shares. https://finance.yahoo.com/quote/FENG?p=FENG&.tsrc=fin-srch
# SAGE	|	1221	|	6.764x	|	28.97%	|	Sage Therapeutics, Inc. https://finance.yahoo.com/quote/SAGE?p=SAGE&.tsrc=fin-srch
# EC	|	1222	|	0.003x	|	17.59%	|	Ecopetrol S.A. American Depositary Shares https://finance.yahoo.com/quote/EC?p=EC&.tsrc=fin-srch
# GBL	|	1223	|	8.051x	|	47.56%	|	Gamco Investors, Inc. Common Stock https://finance.yahoo.com/quote/GBL?p=GBL&.tsrc=fin-srch
# TGS	|	1226	|	0.076x	|	17.89%	|	Transportadora de Gas del Sur SA TGS Common Stock https://finance.yahoo.com/quote/TGS?p=TGS&.tsrc=fin-srch
# MOMO	|	1236	|	2.144x	|	19.46%	|	Momo Inc. https://finance.yahoo.com/quote/MOMO?p=MOMO&.tsrc=fin-srch
# BSBR	|	1239	|	4.591x	|	21.84%	|	Banco Santander Brasil SA American Depositary Shares, each representing one unit https://finance.yahoo.com/quote/BSBR?p=BSBR&.tsrc=fin-srch
# PRDO	|	1270	|	6.608x	|	23.77%	|	Perdoceo Education Corporation https://finance.yahoo.com/quote/PRDO?p=PRDO&.tsrc=fin-srch
# GGAL	|	1271	|	0.089x	|	16.54%	|	Grupo Financiero Galicia S.A. https://finance.yahoo.com/quote/GGAL?p=GGAL&.tsrc=fin-srch
# VNO	|	1275	|	4.025x	|	19.70%	|	Vornado Realty Trust Common Stock https://finance.yahoo.com/quote/VNO?p=VNO&.tsrc=fin-srch
# AIH	|	1279	|	3.960x	|	19.49%	|	Aesthetic Medical International Holdings Group Ltd. https://finance.yahoo.com/quote/AIH?p=AIH&.tsrc=fin-srch
# NSH	|	1290	|	8.836x	|	36.84%	|	Nustar GP Holdings, LLC Units https://finance.yahoo.com/quote/NSH?p=NSH&.tsrc=fin-srch
# LGIH	|	1291	|	7.641x	|	25.69%	|	LGI Homes, Inc. https://finance.yahoo.com/quote/LGIH?p=LGIH&.tsrc=fin-srch
# CE	|	1293	|	7.624x	|	25.19%	|	Celanese Corporation Celanese Corporation Series A Common Stock https://finance.yahoo.com/quote/CE?p=CE&.tsrc=fin-srch
# ATHM	|	1295	|	3.864x	|	18.77%	|	Autohome Inc. American Depositary Shares, each representing one class A ordinary share. https://finance.yahoo.com/quote/ATHM?p=ATHM&.tsrc=fin-srch
# ERIC	|	1299	|	2.370x	|	17.31%	|	Ericsson https://finance.yahoo.com/quote/ERIC?p=ERIC&.tsrc=fin-srch
# FANH	|	1311	|	7.050x	|	22.50%	|	Fanhua Inc. https://finance.yahoo.com/quote/FANH?p=FANH&.tsrc=fin-srch
# EBAY	|	1315	|	7.080x	|	22.34%	|	eBay Inc. https://finance.yahoo.com/quote/EBAY?p=EBAY&.tsrc=fin-srch
# USNA	|	1318	|	9.676x	|	43.85%	|	USANA Health Sciences, Inc. Common Stock https://finance.yahoo.com/quote/USNA?p=USNA&.tsrc=fin-srch
# HBT	|	1324	|	5.721x	|	19.47%	|	HBT Financial, Inc. https://finance.yahoo.com/quote/HBT?p=HBT&.tsrc=fin-srch
# LPX	|	1325	|	9.369x	|	34.50%	|	Louisiana https://finance.yahoo.com/quote/LPX?p=LPX&.tsrc=fin-srch
# TNH	|	1329	|	9.754x	|	41.70%	|	Terra Nitrogen Company, L.P. Common Units https://finance.yahoo.com/quote/TNH?p=TNH&.tsrc=fin-srch
# GMAB	|	1346	|	6.753x	|	20.13%	|	Genmab A/S https://finance.yahoo.com/quote/GMAB?p=GMAB&.tsrc=fin-srch
# MBT	|	1357	|	0.172x	|	14.07%	|	Mobile TeleSystems OJSC https://finance.yahoo.com/quote/MBT?p=MBT&.tsrc=fin-srch
# KBH	|	1358	|	10.244x	|	51.65%	|	KB Home Common Stock https://finance.yahoo.com/quote/KBH?p=KBH&.tsrc=fin-srch
# VMD	|	1361	|	10.406x	|	62.22%	|	Viemed Healthcare, Inc. https://finance.yahoo.com/quote/VMD?p=VMD&.tsrc=fin-srch
# NLOK	|	1365	|	3.300x	|	16.02%	|	NortonLifeLock Inc. https://finance.yahoo.com/quote/NLOK?p=NLOK&.tsrc=fin-srch
# GPM	|	1366	|	4.143x	|	16.73%	|	Guggenheim Enhanced Equity Income Fund https://finance.yahoo.com/quote/GPM?p=GPM&.tsrc=fin-srch
# MCBS	|	1366	|	9.379x	|	27.69%	|	MetroCity Bankshares, Inc. https://finance.yahoo.com/quote/MCBS?p=MCBS&.tsrc=fin-srch
# PBFX	|	1368	|	3.970x	|	16.57%	|	PBF Logistics LP Common Units representing limited partner interests https://finance.yahoo.com/quote/PBFX?p=PBFX&.tsrc=fin-srch
# UHS	|	1382	|	11.080x	|	11386.88%	|	Universal Health Services, Inc. Common Stock https://finance.yahoo.com/quote/UHS?p=UHS&.tsrc=fin-srch
# ASR	|	1384	|	1.077x	|	13.94%	|	Grupo Aeroportuario del Sureste, S.A. de C.V. Common Stock https://finance.yahoo.com/quote/ASR?p=ASR&.tsrc=fin-srch
# BABA	|	1387	|	3.563x	|	15.56%	|	Alibaba Group Holding Limited American Depositary Shares each representing one Ordinary share https://finance.yahoo.com/quote/BABA?p=BABA&.tsrc=fin-srch
# VIRT	|	1405	|	3.040x	|	14.70%	|	Virtu Financial, Inc. https://finance.yahoo.com/quote/VIRT?p=VIRT&.tsrc=fin-srch
# FIZZ	|	1407	|	10.431x	|	33.43%	|	National Beverage Corp. https://finance.yahoo.com/quote/FIZZ?p=FIZZ&.tsrc=fin-srch
# ESGR	|	1412	|	4.630x	|	15.74%	|	Enstar Group Limited https://finance.yahoo.com/quote/ESGR?p=ESGR&.tsrc=fin-srch
# BRK.B	|	1413	|	0.005x	|	12.88%	|	Berkshire Hathaway Inc. New Common Stock https://finance.yahoo.com/quote/BRK.B?p=BRK.B&.tsrc=fin-srch
# HPQ	|	1415	|	10.896x	|	38.19%	|	Hewlett https://finance.yahoo.com/quote/HPQ?p=HPQ&.tsrc=fin-srch
# AMTD	|	1423	|	9.648x	|	23.82%	|	TD Ameritrade Holding Corporation Common Stock https://finance.yahoo.com/quote/AMTD?p=AMTD&.tsrc=fin-srch
# DOOO	|	1429	|	10.230x	|	26.86%	|	BRP Inc. https://finance.yahoo.com/quote/DOOO?p=DOOO&.tsrc=fin-srch
# FF	|	1432	|	5.665x	|	15.84%	|	FutureFuel Corp.  Common shares https://finance.yahoo.com/quote/FF?p=FF&.tsrc=fin-srch
# IMKTA	|	1432	|	4.171x	|	14.92%	|	Ingles Markets, Incorporated https://finance.yahoo.com/quote/IMKTA?p=IMKTA&.tsrc=fin-srch
# FLGT	|	1436	|	11.374x	|	51.14%	|	Fulgent Genetics, Inc. https://finance.yahoo.com/quote/FLGT?p=FLGT&.tsrc=fin-srch
# BIG	|	1437	|	2.779x	|	13.70%	|	Big Lots, Inc. Common Stock https://finance.yahoo.com/quote/BIG?p=BIG&.tsrc=fin-srch
# HEAR	|	1446	|	11.422x	|	42.03%	|	Turtle Beach Corporation https://finance.yahoo.com/quote/HEAR?p=HEAR&.tsrc=fin-srch
# DNP	|	1447	|	5.743x	|	15.55%	|	DNP Select Income Fund, Inc. Common Stock https://finance.yahoo.com/quote/DNP?p=DNP&.tsrc=fin-srch
# APAM	|	1451	|	11.632x	|	61.00%	|	Artisan Partners Asset Management Inc. Class A Common Stock https://finance.yahoo.com/quote/APAM?p=APAM&.tsrc=fin-srch
# ETW	|	1454	|	2.823x	|	13.45%	|	Eaton Vance Corporation Eaton Vance Tax https://finance.yahoo.com/quote/ETW?p=ETW&.tsrc=fin-srch
# HZO	|	1468	|	8.656x	|	19.38%	|	MarineMax, Inc. Common Stock https://finance.yahoo.com/quote/HZO?p=HZO&.tsrc=fin-srch
# MUSA	|	1470	|	10.193x	|	23.63%	|	Murphy USA Inc. Common Stock https://finance.yahoo.com/quote/MUSA?p=MUSA&.tsrc=fin-srch
# SC	|	1486	|	7.702x	|	16.76%	|	Santander Consumer USA Holdings Inc. Common Stock https://finance.yahoo.com/quote/SC?p=SC&.tsrc=fin-srch
# ETV	|	1487	|	4.083x	|	13.45%	|	Eaton Vance Corporation Eaton Vance Tax https://finance.yahoo.com/quote/ETV?p=ETV&.tsrc=fin-srch
# DKL	|	1490	|	8.094x	|	17.18%	|	Delek Logistics Partners, L.P. Common Units representing Limited Partner Interests https://finance.yahoo.com/quote/DKL?p=DKL&.tsrc=fin-srch
# RGR	|	1492	|	12.234x	|	45.40%	|	Sturm, Ruger & Company, Inc. Common Stock https://finance.yahoo.com/quote/RGR?p=RGR&.tsrc=fin-srch
# REDU	|	1496	|	5.193x	|	13.72%	|	RISE Education Cayman Ltd https://finance.yahoo.com/quote/REDU?p=REDU&.tsrc=fin-srch
# SGC	|	1498	|	8.394x	|	17.80%	|	Superior Group of Companies, Inc. https://finance.yahoo.com/quote/SGC?p=SGC&.tsrc=fin-srch
# CHL	|	1500	|	1.623x	|	12.18%	|	China Mobile Limited Common Stock https://finance.yahoo.com/quote/CHL?p=CHL&.tsrc=fin-srch
# MTH	|	1502	|	7.221x	|	15.73%	|	Meritage Homes Corporation Common Stock https://finance.yahoo.com/quote/MTH?p=MTH&.tsrc=fin-srch
# DST	|	1503	|	11.328x	|	27.04%	|	DST Systems, Inc. Common Stock https://finance.yahoo.com/quote/DST?p=DST&.tsrc=fin-srch
# LBC	|	1505	|	12.542x	|	75.76%	|	Luther Burbank Corporation https://finance.yahoo.com/quote/LBC?p=LBC&.tsrc=fin-srch
# SYF	|	1505	|	5.924x	|	13.98%	|	Synchrony Financial Common Stock https://finance.yahoo.com/quote/SYF?p=SYF&.tsrc=fin-srch
# NLS	|	1508	|	12.289x	|	38.57%	|	Nautilus, Inc. Common Stock https://finance.yahoo.com/quote/NLS?p=NLS&.tsrc=fin-srch
# SBR	|	1511	|	12.829x	|	779.71%	|	Sabine Royalty Trust Common Stock https://finance.yahoo.com/quote/SBR?p=SBR&.tsrc=fin-srch
# KBAL	|	1514	|	9.945x	|	20.27%	|	Kimball International, Inc. https://finance.yahoo.com/quote/KBAL?p=KBAL&.tsrc=fin-srch
# PHM	|	1523	|	8.487x	|	16.90%	|	PulteGroup, Inc. Common Stock https://finance.yahoo.com/quote/PHM?p=PHM&.tsrc=fin-srch
# MTOR	|	1525	|	7.335x	|	15.11%	|	Meritor, Inc. Common Stock https://finance.yahoo.com/quote/MTOR?p=MTOR&.tsrc=fin-srch
# LL	|	1525	|	13.123x	|	12413.99%	|	Lumber Liquidators Holdings, Inc Common Stock https://finance.yahoo.com/quote/LL?p=LL&.tsrc=fin-srch
# HCLP	|	1526	|	3.886x	|	12.74%	|	Hi https://finance.yahoo.com/quote/HCLP?p=HCLP&.tsrc=fin-srch
# JGH	|	1532	|	4.974x	|	13.09%	|	Nuveen Global High Income Fund Common Shares of Beneficial Interest https://finance.yahoo.com/quote/JGH?p=JGH&.tsrc=fin-srch
# TPX	|	1533	|	9.836x	|	19.37%	|	Tempur Sealy International, Inc. Common Stock https://finance.yahoo.com/quote/TPX?p=TPX&.tsrc=fin-srch
# BIIB	|	1541	|	11.366x	|	24.18%	|	Biogen Inc. https://finance.yahoo.com/quote/BIIB?p=BIIB&.tsrc=fin-srch
# QDEL	|	1541	|	13.047x	|	67.81%	|	Quidel Corporation https://finance.yahoo.com/quote/QDEL?p=QDEL&.tsrc=fin-srch
# CPL	|	1545	|	6.801x	|	13.90%	|	CPFL Energia S.A. CPFL Energia S.A. American Depositary Shares https://finance.yahoo.com/quote/CPL?p=CPL&.tsrc=fin-srch
# SIVB	|	1550	|	11.331x	|	23.62%	|	SVB Financial Group https://finance.yahoo.com/quote/SIVB?p=SIVB&.tsrc=fin-srch
# CHRS	|	1551	|	10.186x	|	19.50%	|	Coherus BioSciences, Inc. https://finance.yahoo.com/quote/CHRS?p=CHRS&.tsrc=fin-srch
# RY	|	1554	|	9.121x	|	17.05%	|	Royal Bank Of Canada Common Stock https://finance.yahoo.com/quote/RY?p=RY&.tsrc=fin-srch
# PFBC	|	1554	|	10.021x	|	19.14%	|	Preferred Bank https://finance.yahoo.com/quote/PFBC?p=PFBC&.tsrc=fin-srch
# NOAH	|	1558	|	2.520x	|	11.67%	|	Noah Holdings Limited https://finance.yahoo.com/quote/NOAH?p=NOAH&.tsrc=fin-srch
# BCX	|	1559	|	6.287x	|	13.24%	|	BlackRock Resources Common Shares of Beneficial Interest https://finance.yahoo.com/quote/BCX?p=BCX&.tsrc=fin-srch
# BCC	|	1563	|	10.627x	|	19.86%	|	Boise Cascade, L.L.C. Common Stock https://finance.yahoo.com/quote/BCC?p=BCC&.tsrc=fin-srch
# SBS	|	1565	|	2.937x	|	11.69%	|	Companhia de saneamento Basico Do Estado De Sao Paulo https://finance.yahoo.com/quote/SBS?p=SBS&.tsrc=fin-srch
# EQC	|	1567	|	8.131x	|	15.09%	|	Equity Commonwealth Common Shares of Beneficial Interest https://finance.yahoo.com/quote/EQC?p=EQC&.tsrc=fin-srch
# SFM	|	1569	|	8.858x	|	16.31%	|	Sprouts Farmers Market, Inc. https://finance.yahoo.com/quote/SFM?p=SFM&.tsrc=fin-srch
# BAP	|	1571	|	3.921x	|	11.99%	|	Credicorp Ltd. Common Stock https://finance.yahoo.com/quote/BAP?p=BAP&.tsrc=fin-srch
# ITIC	|	1571	|	9.639x	|	17.43%	|	Investors Title Company https://finance.yahoo.com/quote/ITIC?p=ITIC&.tsrc=fin-srch
# SCS	|	1576	|	6.355x	|	13.08%	|	Steelcase Inc. Common Stock https://finance.yahoo.com/quote/SCS?p=SCS&.tsrc=fin-srch
# DFP	|	1579	|	5.388x	|	12.44%	|	Flaherty & Crumrine Dynamic Preferred and Income Fund Inc. Common Stock https://finance.yahoo.com/quote/DFP?p=DFP&.tsrc=fin-srch
# MHO	|	1581	|	5.731x	|	12.62%	|	M/I Homes, Inc. Common Stock https://finance.yahoo.com/quote/MHO?p=MHO&.tsrc=fin-srch
# BKE	|	1581	|	10.793x	|	19.81%	|	Buckle, Inc. (The) Common Stock https://finance.yahoo.com/quote/BKE?p=BKE&.tsrc=fin-srch
# NTAP	|	1583	|	12.057x	|	24.17%	|	NetApp, Inc. https://finance.yahoo.com/quote/NTAP?p=NTAP&.tsrc=fin-srch
# PSXP	|	1588	|	5.324x	|	12.24%	|	Phillips 66 Partners LP Common Units representing limited partner interest in the Partnership https://finance.yahoo.com/quote/PSXP?p=PSXP&.tsrc=fin-srch
# ELP	|	1589	|	1.684x	|	10.85%	|	Companhia Paranaense de Energia (COPEL) Common Stock https://finance.yahoo.com/quote/ELP?p=ELP&.tsrc=fin-srch
# GRBK	|	1594	|	8.543x	|	15.08%	|	Green Brick Partners, Inc. https://finance.yahoo.com/quote/GRBK?p=GRBK&.tsrc=fin-srch
# SGU	|	1596	|	8.795x	|	15.50%	|	Star Gas Partners, L.P. Common Stock https://finance.yahoo.com/quote/SGU?p=SGU&.tsrc=fin-srch
# CPRX	|	1597	|	13.532x	|	37.85%	|	Catalyst Pharmaceuticals, Inc. https://finance.yahoo.com/quote/CPRX?p=CPRX&.tsrc=fin-srch
# MDC	|	1601	|	8.315x	|	14.44%	|	M.D.C. Holdings, Inc. Common Stock https://finance.yahoo.com/quote/MDC?p=MDC&.tsrc=fin-srch
# ONE	|	1607	|	4.839x	|	11.79%	|	Higher One Holdings, Inc. Common Stock https://finance.yahoo.com/quote/ONE?p=ONE&.tsrc=fin-srch
# NNI	|	1608	|	7.816x	|	13.55%	|	Nelnet, Inc. Common Stock https://finance.yahoo.com/quote/NNI?p=NNI&.tsrc=fin-srch
# BXC	|	1611	|	4.323x	|	11.61%	|	Bluelinx Holdings Inc. Common Stock https://finance.yahoo.com/quote/BXC?p=BXC&.tsrc=fin-srch
# BRK.A	|	1611	|	6.864x	|	12.88%	|	Berkshire Hathaway Inc. Common Stock https://finance.yahoo.com/quote/BRK.A?p=BRK.A&.tsrc=fin-srch
# UFPI	|	1612	|	10.213x	|	17.57%	|	UFP Industries, Inc. https://finance.yahoo.com/quote/UFPI?p=UFPI&.tsrc=fin-srch
# INTC	|	1615	|	11.139x	|	19.54%	|	Intel Corporation https://finance.yahoo.com/quote/INTC?p=INTC&.tsrc=fin-srch
# MC	|	1617	|	14.003x	|	41.96%	|	Moelis & Company Class A Common Stock https://finance.yahoo.com/quote/MC?p=MC&.tsrc=fin-srch
# CCU	|	1623	|	0.026x	|	9.92%	|	Compania Cervecerias Unidas, S.A. Common Stock https://finance.yahoo.com/quote/CCU?p=CCU&.tsrc=fin-srch
# JD	|	1624	|	4.599x	|	11.44%	|	JD.com, Inc. https://finance.yahoo.com/quote/JD?p=JD&.tsrc=fin-srch
# DHI	|	1625	|	10.248x	|	17.19%	|	D.R. Horton, Inc. Common Stock https://finance.yahoo.com/quote/DHI?p=DHI&.tsrc=fin-srch
# APO	|	1625	|	11.451x	|	20.21%	|	Apollo Global Management, LLC Class A Common Shares Representing Class A Limitied Liability Company Interests https://finance.yahoo.com/quote/APO?p=APO&.tsrc=fin-srch
# CHT	|	1627	|	0.847x	|	10.19%	|	Chunghwa Telecom Co., Ltd. https://finance.yahoo.com/quote/CHT?p=CHT&.tsrc=fin-srch
# DHIL	|	1627	|	12.325x	|	22.99%	|	Diamond Hill Investment Group, Inc. https://finance.yahoo.com/quote/DHIL?p=DHIL&.tsrc=fin-srch
# EBR	|	1628	|	0.579x	|	10.05%	|	Centrais Elc Braz Pfb B Elbras American Depositary Shares https://finance.yahoo.com/quote/EBR?p=EBR&.tsrc=fin-srch
# PM	|	1636	|	14.470x	|	43.46%	|	Philip Morris International Inc Common Stock https://finance.yahoo.com/quote/PM?p=PM&.tsrc=fin-srch
# OCSL	|	1640	|	5.799x	|	11.68%	|	Oaktree Specialty Lending Corporation https://finance.yahoo.com/quote/OCSL?p=OCSL&.tsrc=fin-srch
# COP	|	1643	|	9.463x	|	15.01%	|	ConocoPhillips Common Stock https://finance.yahoo.com/quote/COP?p=COP&.tsrc=fin-srch
# EVR	|	1643	|	12.620x	|	23.44%	|	Evercore Partners Inc Class A Common Stock https://finance.yahoo.com/quote/EVR?p=EVR&.tsrc=fin-srch
# HVT	|	1650	|	10.063x	|	16.08%	|	Haverty Furniture Companies, Inc. Common Stock https://finance.yahoo.com/quote/HVT?p=HVT&.tsrc=fin-srch
# FII	|	1651	|	12.435x	|	22.15%	|	Federated Investors, Inc. Common Stock https://finance.yahoo.com/quote/FII?p=FII&.tsrc=fin-srch
# EA	|	1654	|	11.016x	|	17.85%	|	Electronic Arts Inc. https://finance.yahoo.com/quote/EA?p=EA&.tsrc=fin-srch
# TROW	|	1657	|	14.079x	|	30.96%	|	T. Rowe Price Group, Inc. https://finance.yahoo.com/quote/TROW?p=TROW&.tsrc=fin-srch
# FL	|	1659	|	7.481x	|	12.46%	|	Foot Locker, Inc. https://finance.yahoo.com/quote/FL?p=FL&.tsrc=fin-srch
# TKC	|	1662	|	1.596x	|	9.95%	|	Turkcell Iletisim Hizmetleri AS Common Stock https://finance.yahoo.com/quote/TKC?p=TKC&.tsrc=fin-srch
# PGR	|	1670	|	8.940x	|	13.61%	|	Progressive Corporation (The) Common Stock https://finance.yahoo.com/quote/PGR?p=PGR&.tsrc=fin-srch
# BBY	|	1674	|	13.850x	|	26.46%	|	Best Buy Co., Inc. Common Stock https://finance.yahoo.com/quote/BBY?p=BBY&.tsrc=fin-srch
# ESCA	|	1675	|	11.609x	|	18.85%	|	Escalade, Incorporated https://finance.yahoo.com/quote/ESCA?p=ESCA&.tsrc=fin-srch
# SPWR	|	1681	|	15.661x	|	147.18%	|	SunPower Corporation https://finance.yahoo.com/quote/SPWR?p=SPWR&.tsrc=fin-srch
# VLP	|	1683	|	11.076x	|	16.84%	|	Valero Energy Partners LP Common Units representing limited partner interests https://finance.yahoo.com/quote/VLP?p=VLP&.tsrc=fin-srch
# CAPL	|	1684	|	6.608x	|	11.47%	|	CrossAmerica Partners LP Common Units representing limited partner interests https://finance.yahoo.com/quote/CAPL?p=CAPL&.tsrc=fin-srch
# HII	|	1687	|	9.358x	|	13.66%	|	Huntington Ingalls Industries, Inc. Common Stock https://finance.yahoo.com/quote/HII?p=HII&.tsrc=fin-srch
# TD	|	1688	|	9.052x	|	13.44%	|	Toronto Dominion Bank (The) Common Stock https://finance.yahoo.com/quote/TD?p=TD&.tsrc=fin-srch
# MIK	|	1690	|	8.372x	|	12.82%	|	The Michaels Companies, Inc. https://finance.yahoo.com/quote/MIK?p=MIK&.tsrc=fin-srch
# UNM	|	1690	|	5.233x	|	10.72%	|	Unum Group Common Stock https://finance.yahoo.com/quote/UNM?p=UNM&.tsrc=fin-srch
# NMIH	|	1694	|	8.354x	|	12.74%	|	NMI Holdings Inc https://finance.yahoo.com/quote/NMIH?p=NMIH&.tsrc=fin-srch
# AB	|	1694	|	12.132x	|	19.20%	|	Allianceberstein Holding L.P.  Units https://finance.yahoo.com/quote/AB?p=AB&.tsrc=fin-srch
# LMT	|	1696	|	13.187x	|	22.39%	|	Lockheed Martin Corporation Common Stock https://finance.yahoo.com/quote/LMT?p=LMT&.tsrc=fin-srch
# AAWW	|	1697	|	3.798x	|	10.17%	|	Atlas Air Worldwide Holdings https://finance.yahoo.com/quote/AAWW?p=AAWW&.tsrc=fin-srch
# DPG	|	1700	|	6.060x	|	10.85%	|	Duff & Phelps Global Utility Income Fund Inc. Common Stock https://finance.yahoo.com/quote/DPG?p=DPG&.tsrc=fin-srch
# YY	|	1700	|	1.398x	|	9.44%	|	JOYY Inc. https://finance.yahoo.com/quote/YY?p=YY&.tsrc=fin-srch
# YNDX	|	1703	|	1.171x	|	9.34%	|	Yandex N.V. https://finance.yahoo.com/quote/YNDX?p=YNDX&.tsrc=fin-srch
# EMD	|	1710	|	6.467x	|	11.00%	|	Western Asset Emerging Markets Income Fund, Inc. Common Stock https://finance.yahoo.com/quote/EMD?p=EMD&.tsrc=fin-srch
# WAL	|	1713	|	11.662x	|	17.72%	|	Western Alliance Bancorporation Common Stock (DE) https://finance.yahoo.com/quote/WAL?p=WAL&.tsrc=fin-srch
# TEP	|	1714	|	7.536x	|	11.67%	|	Tallgrass Energy Partners, LP Common Units representing limited partner interests https://finance.yahoo.com/quote/TEP?p=TEP&.tsrc=fin-srch
# RCII	|	1723	|	11.303x	|	16.35%	|	Rent-A-Center Inc. https://finance.yahoo.com/quote/RCII?p=RCII&.tsrc=fin-srch
# AVAL	|	1726	|	0.003x	|	8.73%	|	Grupo Aval Acciones y Valores S.A. ADR (Each representing 20 preferred shares) https://finance.yahoo.com/quote/AVAL?p=AVAL&.tsrc=fin-srch
# HIFS	|	1728	|	12.911x	|	20.04%	|	Hingham Institution for Savings https://finance.yahoo.com/quote/HIFS?p=HIFS&.tsrc=fin-srch
# MGA	|	1729	|	9.195x	|	12.88%	|	Magna International, Inc. Common Stock https://finance.yahoo.com/quote/MGA?p=MGA&.tsrc=fin-srch
# CCS	|	1731	|	7.585x	|	11.43%	|	Century Communities, Inc. Common Stock https://finance.yahoo.com/quote/CCS?p=CCS&.tsrc=fin-srch
# SNV	|	1737	|	9.696x	|	13.20%	|	Synovus Financial Corp. Common Stock https://finance.yahoo.com/quote/SNV?p=SNV&.tsrc=fin-srch
# SFBS	|	1749	|	13.417x	|	20.60%	|	ServisFirst Bancshares, Inc. https://finance.yahoo.com/quote/SFBS?p=SFBS&.tsrc=fin-srch
# STX	|	1752	|	11.800x	|	16.62%	|	Seagate Technology PLC https://finance.yahoo.com/quote/STX?p=STX&.tsrc=fin-srch
# ASX	|	1761	|	0.515x	|	8.69%	|	Advanced Semiconductor Engineering, Inc. Common Stock https://finance.yahoo.com/quote/ASX?p=ASX&.tsrc=fin-srch
# AVX	|	1763	|	10.160x	|	13.33%	|	AVX Corporation Common Stock https://finance.yahoo.com/quote/AVX?p=AVX&.tsrc=fin-srch
# CO	|	1764	|	0.767x	|	8.71%	|	China Cord Blood Corporation Common Stock https://finance.yahoo.com/quote/CO?p=CO&.tsrc=fin-srch
# TARO	|	1767	|	10.883x	|	14.07%	|	Taro Pharmaceutical Industries Ltd. Ordinary Shares https://finance.yahoo.com/quote/TARO?p=TARO&.tsrc=fin-srch
# BBSI	|	1768	|	14.149x	|	21.30%	|	Barrett Business Services, Inc. https://finance.yahoo.com/quote/BBSI?p=BBSI&.tsrc=fin-srch
# LEGH	|	1768	|	11.918x	|	16.22%	|	Legacy Housing Corporation https://finance.yahoo.com/quote/LEGH?p=LEGH&.tsrc=fin-srch
# OIA	|	1770	|	6.411x	|	10.24%	|	Invesco Municipal Income Opportunities Trust Common Stock https://finance.yahoo.com/quote/OIA?p=OIA&.tsrc=fin-srch
# OZK	|	1772	|	8.509x	|	11.65%	|	Bank OZK https://finance.yahoo.com/quote/OZK?p=OZK&.tsrc=fin-srch
# ABG	|	1773	|	10.763x	|	13.78%	|	Asbury Automotive Group Inc Common Stock https://finance.yahoo.com/quote/ABG?p=ABG&.tsrc=fin-srch
# SFST	|	1773	|	11.157x	|	14.68%	|	Southern First Bancshares, Inc. https://finance.yahoo.com/quote/SFST?p=SFST&.tsrc=fin-srch
# REGN	|	1773	|	15.661x	|	26.54%	|	Regeneron Pharmaceuticals, Inc. https://finance.yahoo.com/quote/REGN?p=REGN&.tsrc=fin-srch
# AZO	|	1773	|	15.697x	|	27.23%	|	AutoZone, Inc. Common Stock https://finance.yahoo.com/quote/AZO?p=AZO&.tsrc=fin-srch
# BG	|	1775	|	8.105x	|	11.15%	|	Bunge Limited Bunge Limited https://finance.yahoo.com/quote/BG?p=BG&.tsrc=fin-srch
# TRMD	|	1775	|	3.766x	|	9.22%	|	TORM plc https://finance.yahoo.com/quote/TRMD?p=TRMD&.tsrc=fin-srch
# BRSS	|	1781	|	11.125x	|	14.27%	|	Global Brass and Copper Holdings, Inc. Common Stock https://finance.yahoo.com/quote/BRSS?p=BRSS&.tsrc=fin-srch
# AFG	|	1781	|	11.135x	|	14.31%	|	American Financial Group, Inc. Common Stock https://finance.yahoo.com/quote/AFG?p=AFG&.tsrc=fin-srch
# RIO	|	1781	|	11.238x	|	14.50%	|	Rio Tinto Plc Common Stock https://finance.yahoo.com/quote/RIO?p=RIO&.tsrc=fin-srch
# UNH	|	1784	|	12.311x	|	16.61%	|	UnitedHealth Group Incorporated Common Stock https://finance.yahoo.com/quote/UNH?p=UNH&.tsrc=fin-srch
# PLCE	|	1787	|	11.557x	|	15.08%	|	Children's Place, Inc. (The) https://finance.yahoo.com/quote/PLCE?p=PLCE&.tsrc=fin-srch
# CROX	|	1797	|	15.746x	|	25.02%	|	Crocs, Inc. https://finance.yahoo.com/quote/CROX?p=CROX&.tsrc=fin-srch
# BSMX	|	1797	|	0.481x	|	8.26%	|	Grupo Financiero Santander Mexico S.A. B. de C.V. American Depositary Shares, each representing five Series B shares https://finance.yahoo.com/quote/BSMX?p=BSMX&.tsrc=fin-srch
# FISI	|	1798	|	9.931x	|	12.43%	|	Financial Institutions, Inc. https://finance.yahoo.com/quote/FISI?p=FISI&.tsrc=fin-srch
# KGC	|	1800	|	8.783x	|	11.39%	|	Kinross Gold Corporation Common Stock https://finance.yahoo.com/quote/KGC?p=KGC&.tsrc=fin-srch
# DECK	|	1800	|	15.291x	|	23.28%	|	Deckers Outdoor Corporation Common Stock https://finance.yahoo.com/quote/DECK?p=DECK&.tsrc=fin-srch
# EBF	|	1802	|	12.137x	|	15.64%	|	Ennis, Inc. Common Stock https://finance.yahoo.com/quote/EBF?p=EBF&.tsrc=fin-srch
# CMC	|	1805	|	8.521x	|	11.11%	|	Commercial Metals Company Common Stock https://finance.yahoo.com/quote/CMC?p=CMC&.tsrc=fin-srch
# GPI	|	1808	|	8.948x	|	11.41%	|	Group 1 Automotive, Inc. Common Stock https://finance.yahoo.com/quote/GPI?p=GPI&.tsrc=fin-srch
# DGX	|	1809	|	12.094x	|	15.38%	|	Quest Diagnostics Incorporated Common Stock https://finance.yahoo.com/quote/DGX?p=DGX&.tsrc=fin-srch
# SNA	|	1809	|	12.642x	|	16.68%	|	Snap https://finance.yahoo.com/quote/SNA?p=SNA&.tsrc=fin-srch
# MFC	|	1810	|	7.462x	|	10.27%	|	Manulife Financial Corporation Common Stock https://finance.yahoo.com/quote/MFC?p=MFC&.tsrc=fin-srch
# NAC	|	1810	|	5.705x	|	9.37%	|	Nuveen California Dividend Advantage Municipal Fund Common Stock https://finance.yahoo.com/quote/NAC?p=NAC&.tsrc=fin-srch
# ACGL	|	1811	|	10.922x	|	13.35%	|	Arch Capital Group Ltd. https://finance.yahoo.com/quote/ACGL?p=ACGL&.tsrc=fin-srch
# PLUS	|	1814	|	13.649x	|	18.37%	|	ePlus inc. https://finance.yahoo.com/quote/PLUS?p=PLUS&.tsrc=fin-srch
# ZUMZ	|	1814	|	9.824x	|	12.06%	|	Zumiez Inc. https://finance.yahoo.com/quote/ZUMZ?p=ZUMZ&.tsrc=fin-srch
# HUM	|	1815	|	15.042x	|	21.32%	|	Humana Inc. Common Stock https://finance.yahoo.com/quote/HUM?p=HUM&.tsrc=fin-srch
# IRWD	|	1817	|	14.785x	|	20.65%	|	Ironwood Pharmaceuticals, Inc. https://finance.yahoo.com/quote/IRWD?p=IRWD&.tsrc=fin-srch
# CYD	|	1819	|	0.806x	|	8.17%	|	China Yuchai International Limited Common Stock https://finance.yahoo.com/quote/CYD?p=CYD&.tsrc=fin-srch
# GOOG	|	1819	|	13.668x	|	18.30%	|	Alphabet Inc. https://finance.yahoo.com/quote/GOOG?p=GOOG&.tsrc=fin-srch
# WSM	|	1822	|	13.898x	|	18.70%	|	Williams https://finance.yahoo.com/quote/WSM?p=WSM&.tsrc=fin-srch
# FIX	|	1823	|	13.606x	|	17.99%	|	Comfort Systems USA, Inc. Common Stock https://finance.yahoo.com/quote/FIX?p=FIX&.tsrc=fin-srch
# SEIC	|	1830	|	17.335x	|	30.74%	|	SEI Investments Company https://finance.yahoo.com/quote/SEIC?p=SEIC&.tsrc=fin-srch
# HIG	|	1833	|	10.303x	|	12.42%	|	Hartford Financial Services Group, Inc. (The) Common Stock https://finance.yahoo.com/quote/HIG?p=HIG&.tsrc=fin-srch
# RNR	|	1837	|	11.115x	|	13.15%	|	RenaissanceRe Holdings Ltd. Common Stock https://finance.yahoo.com/quote/RNR?p=RNR&.tsrc=fin-srch
# SCPL	|	1839	|	17.422x	|	29.85%	|	SciPlay Corporation https://finance.yahoo.com/quote/SCPL?p=SCPL&.tsrc=fin-srch
# TCPC	|	1840	|	7.906x	|	10.19%	|	BlackRock TCP Capital Corp. https://finance.yahoo.com/quote/TCPC?p=TCPC&.tsrc=fin-srch
# BSRR	|	1843	|	11.666x	|	13.86%	|	Sierra Bancorp https://finance.yahoo.com/quote/BSRR?p=BSRR&.tsrc=fin-srch
# SF	|	1859	|	10.633x	|	12.12%	|	Stifel Financial Corporation Common Stock https://finance.yahoo.com/quote/SF?p=SF&.tsrc=fin-srch
# ORLY	|	1861	|	18.692x	|	35.78%	|	O'Reilly Automotive, Inc. https://finance.yahoo.com/quote/ORLY?p=ORLY&.tsrc=fin-srch
# CBPX	|	1867	|	12.915x	|	15.54%	|	Continental Building Products, Inc. Common Stock https://finance.yahoo.com/quote/CBPX?p=CBPX&.tsrc=fin-srch
# ZION	|	1870	|	10.085x	|	11.61%	|	Zions Bancorporation N.A. https://finance.yahoo.com/quote/ZION?p=ZION&.tsrc=fin-srch
# WHR	|	1870	|	10.715x	|	12.10%	|	Whirlpool Corporation Common Stock https://finance.yahoo.com/quote/WHR?p=WHR&.tsrc=fin-srch
# CCNE	|	1872	|	11.398x	|	12.95%	|	CNB Financial Corporation https://finance.yahoo.com/quote/CCNE?p=CCNE&.tsrc=fin-srch
# TNET	|	1873	|	18.255x	|	30.43%	|	TriNet Group, Inc. Common Stock https://finance.yahoo.com/quote/TNET?p=TNET&.tsrc=fin-srch
# MSM	|	1873	|	13.921x	|	16.94%	|	MSC Industrial Direct Company, Inc. Common Stock https://finance.yahoo.com/quote/MSM?p=MSM&.tsrc=fin-srch
# NATR	|	1875	|	13.656x	|	16.45%	|	Nature's Sunshine Products, Inc. https://finance.yahoo.com/quote/NATR?p=NATR&.tsrc=fin-srch
# SNP	|	1875	|	1.149x	|	7.63%	|	China Petroleum & Chemical Corporation Common Stock https://finance.yahoo.com/quote/SNP?p=SNP&.tsrc=fin-srch
# LEN	|	1875	|	9.794x	|	11.08%	|	Lennar Corporation Class A Common Stock https://finance.yahoo.com/quote/LEN?p=LEN&.tsrc=fin-srch
# CIB	|	1878	|	0.004x	|	7.31%	|	BanColombia S.A. Common Stock https://finance.yahoo.com/quote/CIB?p=CIB&.tsrc=fin-srch
# TM	|	1884	|	0.083x	|	7.35%	|	Toyota Motor Corporation Common Stock https://finance.yahoo.com/quote/TM?p=TM&.tsrc=fin-srch
# NEU	|	1888	|	15.888x	|	20.43%	|	NewMarket Corp Common Stock https://finance.yahoo.com/quote/NEU?p=NEU&.tsrc=fin-srch
# FCNCA	|	1890	|	13.138x	|	15.22%	|	First Citizens BancShares, Inc. https://finance.yahoo.com/quote/FCNCA?p=FCNCA&.tsrc=fin-srch
# FPF	|	1891	|	7.411x	|	9.29%	|	First Trust Intermediate Duration Preferred & Income Fund Common Shares of Beneficial Interest https://finance.yahoo.com/quote/FPF?p=FPF&.tsrc=fin-srch
# GIII	|	1892	|	7.494x	|	9.33%	|	G-III Apparel Group, LTD. https://finance.yahoo.com/quote/GIII?p=GIII&.tsrc=fin-srch
# SUPN	|	1895	|	12.191x	|	13.40%	|	Supernus Pharmaceuticals, Inc. https://finance.yahoo.com/quote/SUPN?p=SUPN&.tsrc=fin-srch
# LOPE	|	1898	|	15.482x	|	19.30%	|	Grand Canyon Education, Inc. https://finance.yahoo.com/quote/LOPE?p=LOPE&.tsrc=fin-srch
# ECA	|	1899	|	6.285x	|	8.73%	|	Encana Corporation https://finance.yahoo.com/quote/ECA?p=ECA&.tsrc=fin-srch
# CSCO	|	1900	|	15.933x	|	20.09%	|	Cisco Systems, Inc. https://finance.yahoo.com/quote/CSCO?p=CSCO&.tsrc=fin-srch
# NXST	|	1903	|	6.293x	|	8.72%	|	Nexstar Media Group, Inc. https://finance.yahoo.com/quote/NXST?p=NXST&.tsrc=fin-srch
# SBNY	|	1903	|	13.254x	|	15.07%	|	Signature Bank https://finance.yahoo.com/quote/SBNY?p=SBNY&.tsrc=fin-srch
# SY	|	1904	|	4.496x	|	8.19%	|	So-Young International Inc. https://finance.yahoo.com/quote/SY?p=SY&.tsrc=fin-srch
# PLPC	|	1911	|	10.635x	|	11.35%	|	Preformed Line Products Company https://finance.yahoo.com/quote/PLPC?p=PLPC&.tsrc=fin-srch
# PFC	|	1912	|	12.175x	|	13.12%	|	Premier Financial Corp.  https://finance.yahoo.com/quote/PFC?p=PFC&.tsrc=fin-srch
# KOP	|	1912	|	5.726x	|	8.43%	|	Koppers Holdings Inc. Koppers Holdings Inc. Common Stock https://finance.yahoo.com/quote/KOP?p=KOP&.tsrc=fin-srch
# ACBI	|	1914	|	8.273x	|	9.50%	|	Atlantic Capital Bancshares, Inc. https://finance.yahoo.com/quote/ACBI?p=ACBI&.tsrc=fin-srch
# SVA	|	1915	|	15.796x	|	19.40%	|	Sinovac Biotech, Ltd. https://finance.yahoo.com/quote/SVA?p=SVA&.tsrc=fin-srch
# SNBR	|	1915	|	20.758x	|	122.04%	|	Sleep Number Corporation https://finance.yahoo.com/quote/SNBR?p=SNBR&.tsrc=fin-srch
# ALRS	|	1916	|	10.665x	|	11.31%	|	Alerus Financial Corporation https://finance.yahoo.com/quote/ALRS?p=ALRS&.tsrc=fin-srch
# TGT	|	1917	|	21.302x	|	15764.19%	|	Target Corporation Common Stock https://finance.yahoo.com/quote/TGT?p=TGT&.tsrc=fin-srch
# JBSS	|	1919	|	18.229x	|	24.62%	|	John B. Sanfilippo & Son, Inc. https://finance.yahoo.com/quote/JBSS?p=JBSS&.tsrc=fin-srch
# SENEA	|	1919	|	6.369x	|	8.64%	|	Seneca Foods Corp. https://finance.yahoo.com/quote/SENEA?p=SENEA&.tsrc=fin-srch
# SYX	|	1920	|	18.874x	|	27.88%	|	Systemax Inc. Common Stock https://finance.yahoo.com/quote/SYX?p=SYX&.tsrc=fin-srch
# SENEB	|	1921	|	6.408x	|	8.64%	|	Seneca Foods Corp. https://finance.yahoo.com/quote/SENEB?p=SENEB&.tsrc=fin-srch
# CIVB	|	1923	|	10.391x	|	11.00%	|	Civista Bancshares, Inc.  https://finance.yahoo.com/quote/CIVB?p=CIVB&.tsrc=fin-srch
# HLF	|	1924	|	18.792x	|	26.50%	|	Herbalife Ltd. Common Stock https://finance.yahoo.com/quote/HLF?p=HLF&.tsrc=fin-srch
# DNR	|	1924	|	2.118x	|	7.42%	|	Denbury Resources Inc. Common Stock https://finance.yahoo.com/quote/DNR?p=DNR&.tsrc=fin-srch
# ACIU	|	1927	|	14.364x	|	16.13%	|	AC Immune SA https://finance.yahoo.com/quote/ACIU?p=ACIU&.tsrc=fin-srch
# UCBI	|	1927	|	12.252x	|	12.91%	|	United Community Banks, Inc. https://finance.yahoo.com/quote/UCBI?p=UCBI&.tsrc=fin-srch
# STL	|	1930	|	9.878x	|	10.49%	|	Sterling Bancorp https://finance.yahoo.com/quote/STL?p=STL&.tsrc=fin-srch
# TBBK	|	1933	|	12.782x	|	13.45%	|	The Bancorp, Inc. https://finance.yahoo.com/quote/TBBK?p=TBBK&.tsrc=fin-srch
# SCVL	|	1934	|	10.267x	|	10.82%	|	Shoe Carnival, Inc. https://finance.yahoo.com/quote/SCVL?p=SCVL&.tsrc=fin-srch
# DMLP	|	1938	|	18.805x	|	25.29%	|	Dorchester Minerals, L.P. https://finance.yahoo.com/quote/DMLP?p=DMLP&.tsrc=fin-srch
# VMW	|	1938	|	7.839x	|	9.00%	|	Vmware, Inc. Common stock, Class A https://finance.yahoo.com/quote/VMW?p=VMW&.tsrc=fin-srch
# TCOM	|	1941	|	0.380x	|	6.94%	|	Trip.com Group Limited https://finance.yahoo.com/quote/TCOM?p=TCOM&.tsrc=fin-srch
# SNX	|	1941	|	7.844x	|	8.98%	|	Synnex Corporation Common Stock https://finance.yahoo.com/quote/SNX?p=SNX&.tsrc=fin-srch
# VZA	|	1941	|	6.904x	|	8.65%	|	Verizon Communications Inc. 5.90% Notes due 2054 https://finance.yahoo.com/quote/VZA?p=VZA&.tsrc=fin-srch
# SAFT	|	1942	|	8.077x	|	9.07%	|	Safety Insurance Group, Inc. https://finance.yahoo.com/quote/SAFT?p=SAFT&.tsrc=fin-srch
# WMK	|	1943	|	10.796x	|	11.10%	|	Weis Markets, Inc. Common Stock https://finance.yahoo.com/quote/WMK?p=WMK&.tsrc=fin-srch
# JKS	|	1943	|	3.664x	|	7.55%	|	JinkoSolar Holding Company Limited American Depositary Shares (each representing 4 Common Shares) https://finance.yahoo.com/quote/JKS?p=JKS&.tsrc=fin-srch
# CAC	|	1943	|	12.868x	|	13.44%	|	Camden National Corporation https://finance.yahoo.com/quote/CAC?p=CAC&.tsrc=fin-srch
# BPMC	|	1944	|	16.809x	|	19.70%	|	Blueprint Medicines Corporation https://finance.yahoo.com/quote/BPMC?p=BPMC&.tsrc=fin-srch
# PFSI	|	1944	|	2.763x	|	7.38%	|	PennyMac Financial Services, Inc. Class A Common Stock https://finance.yahoo.com/quote/PFSI?p=PFSI&.tsrc=fin-srch
# KMB	|	1945	|	19.135x	|	26.44%	|	Kimberly https://finance.yahoo.com/quote/KMB?p=KMB&.tsrc=fin-srch
# VGM	|	1946	|	7.166x	|	8.70%	|	Invesco Trust for Investment Grade Municipals Common Stock (DE) https://finance.yahoo.com/quote/VGM?p=VGM&.tsrc=fin-srch
# VIAC	|	1948	|	6.356x	|	8.27%	|	ViacomCBS Inc. https://finance.yahoo.com/quote/VIAC?p=VIAC&.tsrc=fin-srch
# ECPG	|	1949	|	4.406x	|	7.67%	|	Encore Capital Group Inc https://finance.yahoo.com/quote/ECPG?p=ECPG&.tsrc=fin-srch
# NAD	|	1950	|	6.779x	|	8.48%	|	Nuveen Dividend Advantage Municipal Fund Common Stock https://finance.yahoo.com/quote/NAD?p=NAD&.tsrc=fin-srch
# JWN	|	1952	|	10.833x	|	10.97%	|	Nordstrom, Inc. Common Stock https://finance.yahoo.com/quote/JWN?p=JWN&.tsrc=fin-srch
# SLF	|	1953	|	9.601x	|	9.94%	|	Sun Life Financial Inc. Common Stock https://finance.yahoo.com/quote/SLF?p=SLF&.tsrc=fin-srch
# BDN	|	1955	|	6.341x	|	8.20%	|	Brandywine Realty Trust Common Stock https://finance.yahoo.com/quote/BDN?p=BDN&.tsrc=fin-srch
# UTHR	|	1957	|	14.024x	|	14.86%	|	United Therapeutics Corporation https://finance.yahoo.com/quote/UTHR?p=UTHR&.tsrc=fin-srch
# NEA	|	1958	|	6.845x	|	8.44%	|	Nuveen AMT https://finance.yahoo.com/quote/NEA?p=NEA&.tsrc=fin-srch
# BT	|	1962	|	9.881x	|	10.00%	|	BT Group plc Common Stock https://finance.yahoo.com/quote/BT?p=BT&.tsrc=fin-srch
# NVR	|	1963	|	18.215x	|	21.85%	|	NVR, Inc. Common Stock https://finance.yahoo.com/quote/NVR?p=NVR&.tsrc=fin-srch
# BOOT	|	1964	|	9.687x	|	9.85%	|	Boot Barn Holdings, Inc. Common Stock https://finance.yahoo.com/quote/BOOT?p=BOOT&.tsrc=fin-srch
# WINA	|	1964	|	22.281x	|	391.72%	|	Winmark Corporation https://finance.yahoo.com/quote/WINA?p=WINA&.tsrc=fin-srch
# SEE	|	1964	|	13.045x	|	13.28%	|	Sealed Air Corporation Common Stock https://finance.yahoo.com/quote/SEE?p=SEE&.tsrc=fin-srch
# KFRC	|	1968	|	17.448x	|	20.28%	|	Kforce, Inc. https://finance.yahoo.com/quote/KFRC?p=KFRC&.tsrc=fin-srch
# SMP	|	1971	|	15.296x	|	16.42%	|	Standard Motor Products, Inc. Common Stock https://finance.yahoo.com/quote/SMP?p=SMP&.tsrc=fin-srch
# BCH	|	1973	|	0.016x	|	6.57%	|	Banco De Chile Banco De Chile ADS https://finance.yahoo.com/quote/BCH?p=BCH&.tsrc=fin-srch
# HOLI	|	1974	|	9.183x	|	9.43%	|	Hollysys Automation Technologies, Ltd. https://finance.yahoo.com/quote/HOLI?p=HOLI&.tsrc=fin-srch
# CNXN	|	1974	|	16.328x	|	17.93%	|	PC Connection, Inc. https://finance.yahoo.com/quote/CNXN?p=CNXN&.tsrc=fin-srch
# HD	|	1976	|	21.837x	|	44.78%	|	Home Depot, Inc. (The) Common Stock https://finance.yahoo.com/quote/HD?p=HD&.tsrc=fin-srch
# IVR	|	1979	|	6.356x	|	7.95%	|	INVESCO MORTGAGE CAPITAL INC Common Stock https://finance.yahoo.com/quote/IVR?p=IVR&.tsrc=fin-srch
# FITB	|	1980	|	8.255x	|	8.88%	|	Fifth Third Bancorp https://finance.yahoo.com/quote/FITB?p=FITB&.tsrc=fin-srch
# HWC	|	1981	|	10.787x	|	10.61%	|	Hancock Whitney Corporation https://finance.yahoo.com/quote/HWC?p=HWC&.tsrc=fin-srch
# GBLI	|	1981	|	6.444x	|	7.99%	|	Global Indemnity Group, LLC https://finance.yahoo.com/quote/GBLI?p=GBLI&.tsrc=fin-srch
# KKR	|	1983	|	8.262x	|	8.87%	|	KKR & Co. L.P. Common Units Representing Limited Partnership Interest https://finance.yahoo.com/quote/KKR?p=KKR&.tsrc=fin-srch
# APOG	|	1983	|	9.198x	|	9.36%	|	Apogee Enterprises, Inc. https://finance.yahoo.com/quote/APOG?p=APOG&.tsrc=fin-srch
# VIVO	|	1984	|	15.808x	|	16.81%	|	Meridian Bioscience Inc. https://finance.yahoo.com/quote/VIVO?p=VIVO&.tsrc=fin-srch
# GPRK	|	1984	|	20.284x	|	26.60%	|	Geopark Ltd Common Shares https://finance.yahoo.com/quote/GPRK?p=GPRK&.tsrc=fin-srch
# NUS	|	1988	|	16.790x	|	18.12%	|	Nu Skin Enterprises, Inc. Common Stock https://finance.yahoo.com/quote/NUS?p=NUS&.tsrc=fin-srch
# IIM	|	1992	|	6.577x	|	7.90%	|	Invesco Value Municipal Income Trust Common Stock https://finance.yahoo.com/quote/IIM?p=IIM&.tsrc=fin-srch
# JOUT	|	1994	|	15.912x	|	16.73%	|	Johnson Outdoors Inc. https://finance.yahoo.com/quote/JOUT?p=JOUT&.tsrc=fin-srch
# WTFC	|	1995	|	10.280x	|	10.05%	|	Wintrust Financial Corporation https://finance.yahoo.com/quote/WTFC?p=WTFC&.tsrc=fin-srch
# QCRH	|	1995	|	11.566x	|	11.23%	|	QCR Holdings, Inc. https://finance.yahoo.com/quote/QCRH?p=QCRH&.tsrc=fin-srch
# VRTS	|	1996	|	13.339x	|	13.10%	|	Virtus Investment Partners, Inc. https://finance.yahoo.com/quote/VRTS?p=VRTS&.tsrc=fin-srch
# LOW	|	2000	|	19.342x	|	23.15%	|	Lowe's Companies, Inc. Common Stock https://finance.yahoo.com/quote/LOW?p=LOW&.tsrc=fin-srch
# INFY	|	2000	|	21.365x	|	31.42%	|	Infosys Limited American Depositary Shares https://finance.yahoo.com/quote/INFY?p=INFY&.tsrc=fin-srch
# CRMT	|	2001	|	10.275x	|	9.98%	|	America's Car-Mart, Inc. https://finance.yahoo.com/quote/CRMT?p=CRMT&.tsrc=fin-srch
# CBS	|	2002	|	7.580x	|	8.27%	|	CBS Corporation Class B Common Stock https://finance.yahoo.com/quote/CBS?p=CBS&.tsrc=fin-srch
# MOH	|	2004	|	18.727x	|	21.04%	|	Molina Healthcare Inc Common Stock https://finance.yahoo.com/quote/MOH?p=MOH&.tsrc=fin-srch
# LOGI	|	2004	|	17.911x	|	19.66%	|	Logitech International S.A. https://finance.yahoo.com/quote/LOGI?p=LOGI&.tsrc=fin-srch
# NPK	|	2006	|	14.533x	|	14.10%	|	National Presto Industries, Inc. Common Stock https://finance.yahoo.com/quote/NPK?p=NPK&.tsrc=fin-srch
# TPH	|	2008	|	9.229x	|	9.07%	|	Tri Pointe Homes, Inc. Common Stock https://finance.yahoo.com/quote/TPH?p=TPH&.tsrc=fin-srch
# MO	|	2012	|	17.087x	|	17.97%	|	Altria Group, Inc. https://finance.yahoo.com/quote/MO?p=MO&.tsrc=fin-srch
# FLY	|	2012	|	2.438x	|	6.78%	|	Fly Leasing Limited https://finance.yahoo.com/quote/FLY?p=FLY&.tsrc=fin-srch
# CPAC	|	2012	|	6.030x	|	7.54%	|	Cementos Pacasmayo S.A.A. American Depositary Shares, each representing five Common Shares https://finance.yahoo.com/quote/CPAC?p=CPAC&.tsrc=fin-srch
# LXP	|	2012	|	9.509x	|	9.12%	|	Lexington Realty Trust Common Stock https://finance.yahoo.com/quote/LXP?p=LXP&.tsrc=fin-srch
# NRK	|	2014	|	6.706x	|	7.70%	|	Nuveen New York AMT https://finance.yahoo.com/quote/NRK?p=NRK&.tsrc=fin-srch
# PGC	|	2014	|	12.053x	|	11.26%	|	Peapack-Gladstone Financial Corporation https://finance.yahoo.com/quote/PGC?p=PGC&.tsrc=fin-srch
# AMKR	|	2014	|	11.003x	|	10.43%	|	Amkor Technology, Inc. https://finance.yahoo.com/quote/AMKR?p=AMKR&.tsrc=fin-srch
# CNOB	|	2014	|	11.562x	|	10.93%	|	ConnectOne Bancorp, Inc. https://finance.yahoo.com/quote/CNOB?p=CNOB&.tsrc=fin-srch
# APH	|	2015	|	15.436x	|	15.23%	|	Amphenol Corporation Common Stock https://finance.yahoo.com/quote/APH?p=APH&.tsrc=fin-srch
# VRTX	|	2018	|	21.951x	|	31.56%	|	Vertex Pharmaceuticals Incorporated https://finance.yahoo.com/quote/VRTX?p=VRTX&.tsrc=fin-srch
# EXPD	|	2020	|	21.977x	|	31.52%	|	Expeditors International of Washington, Inc. https://finance.yahoo.com/quote/EXPD?p=EXPD&.tsrc=fin-srch
# HCA	|	2020	|	14.768x	|	14.00%	|	HCA Holdings, Inc. Common Stock https://finance.yahoo.com/quote/HCA?p=HCA&.tsrc=fin-srch
# CCAP	|	2022	|	8.659x	|	8.72%	|	Crescent Capital BDC, Inc. https://finance.yahoo.com/quote/CCAP?p=CCAP&.tsrc=fin-srch
# CI	|	2025	|	9.647x	|	9.10%	|	Cigna Corporation Common Stock https://finance.yahoo.com/quote/CI?p=CI&.tsrc=fin-srch
# MET	|	2026	|	7.957x	|	8.22%	|	MetLife, Inc. Common Stock https://finance.yahoo.com/quote/MET?p=MET&.tsrc=fin-srch
# LPG	|	2027	|	4.313x	|	7.05%	|	Dorian LPG Ltd. Common Stock https://finance.yahoo.com/quote/LPG?p=LPG&.tsrc=fin-srch
# TSCO	|	2027	|	24.252x	|	18248.61%	|	Tractor Supply Company https://finance.yahoo.com/quote/TSCO?p=TSCO&.tsrc=fin-srch
# LAZ	|	2027	|	11.280x	|	10.53%	|	Lazard LTD. Lazard, LTD. Class A Common Stock https://finance.yahoo.com/quote/LAZ?p=LAZ&.tsrc=fin-srch
# RTEC	|	2029	|	15.121x	|	14.30%	|	Rudolph Technologies, Inc. Common Stock https://finance.yahoo.com/quote/RTEC?p=RTEC&.tsrc=fin-srch
# FMBI	|	2029	|	11.025x	|	10.21%	|	First Midwest Bancorp, Inc. https://finance.yahoo.com/quote/FMBI?p=FMBI&.tsrc=fin-srch
# VCV	|	2032	|	6.969x	|	7.69%	|	Invesco California Value Municipal Income Trust Common Stock https://finance.yahoo.com/quote/VCV?p=VCV&.tsrc=fin-srch
# SCHW	|	2034	|	16.703x	|	16.62%	|	Charles Schwab Corporation (The) Common Stock https://finance.yahoo.com/quote/SCHW?p=SCHW&.tsrc=fin-srch
# MCY	|	2036	|	7.833x	|	8.02%	|	Mercury General Corporation Common Stock https://finance.yahoo.com/quote/MCY?p=MCY&.tsrc=fin-srch
# GNTY	|	2036	|	12.739x	|	11.79%	|	Guaranty Bancshares, Inc. https://finance.yahoo.com/quote/GNTY?p=GNTY&.tsrc=fin-srch
# BSAC	|	2036	|	0.015x	|	6.04%	|	Banco Santander https://finance.yahoo.com/quote/BSAC?p=BSAC&.tsrc=fin-srch
# TSN	|	2037	|	9.776x	|	9.08%	|	Tyson Foods, Inc. Common Stock https://finance.yahoo.com/quote/TSN?p=TSN&.tsrc=fin-srch
# BLDR	|	2040	|	14.226x	|	13.17%	|	Builders FirstSource, Inc. https://finance.yahoo.com/quote/BLDR?p=BLDR&.tsrc=fin-srch
# NODK	|	2040	|	8.868x	|	8.67%	|	NI Holdings, Inc. https://finance.yahoo.com/quote/NODK?p=NODK&.tsrc=fin-srch
# DISH	|	2043	|	7.897x	|	8.00%	|	DISH Network Corporation https://finance.yahoo.com/quote/DISH?p=DISH&.tsrc=fin-srch
# UVE	|	2045	|	22.189x	|	28.40%	|	UNIVERSAL INSURANCE HOLDINGS INC Common Stock https://finance.yahoo.com/quote/UVE?p=UVE&.tsrc=fin-srch
# CFR	|	2046	|	13.109x	|	12.04%	|	Cullen/Frost Bankers, Inc. Common Stock https://finance.yahoo.com/quote/CFR?p=CFR&.tsrc=fin-srch
# BDSI	|	2047	|	15.129x	|	13.89%	|	BioDelivery Sciences International, Inc. https://finance.yahoo.com/quote/BDSI?p=BDSI&.tsrc=fin-srch
# HTHT	|	2049	|	5.875x	|	7.19%	|	Huazhu Group Limited https://finance.yahoo.com/quote/HTHT?p=HTHT&.tsrc=fin-srch
# IESC	|	2052	|	16.177x	|	15.50%	|	IES Holdings, Inc. https://finance.yahoo.com/quote/IESC?p=IESC&.tsrc=fin-srch
# CSIQ	|	2054	|	7.125x	|	7.56%	|	Canadian Solar Inc. https://finance.yahoo.com/quote/CSIQ?p=CSIQ&.tsrc=fin-srch
# HEP	|	2055	|	9.005x	|	8.59%	|	Holly Energy Partners, L.P. Common Stock https://finance.yahoo.com/quote/HEP?p=HEP&.tsrc=fin-srch
# ADP	|	2055	|	23.211x	|	35.21%	|	Automatic Data Processing, Inc. https://finance.yahoo.com/quote/ADP?p=ADP&.tsrc=fin-srch
# OPY	|	2056	|	3.638x	|	6.64%	|	Oppenheimer Holdings, Inc. Class A Common Stock (DE) https://finance.yahoo.com/quote/OPY?p=OPY&.tsrc=fin-srch
# FHN	|	2056	|	11.581x	|	10.51%	|	First Horizon National Corporation Common Stock https://finance.yahoo.com/quote/FHN?p=FHN&.tsrc=fin-srch
# LH	|	2058	|	14.313x	|	13.06%	|	Laboratory Corporation of America Holdings Common Stock https://finance.yahoo.com/quote/LH?p=LH&.tsrc=fin-srch
# MYRG	|	2059	|	15.790x	|	14.73%	|	MYR Group, Inc. https://finance.yahoo.com/quote/MYRG?p=MYRG&.tsrc=fin-srch
# STNE	|	2060	|	15.562x	|	14.10%	|	StoneCo Ltd. https://finance.yahoo.com/quote/STNE?p=STNE&.tsrc=fin-srch
# PRIM	|	2060	|	13.380x	|	12.08%	|	Primoris Services Corporation https://finance.yahoo.com/quote/PRIM?p=PRIM&.tsrc=fin-srch
# ULTA	|	2060	|	21.482x	|	24.32%	|	Ulta Beauty, Inc. https://finance.yahoo.com/quote/ULTA?p=ULTA&.tsrc=fin-srch
# BZUN	|	2061	|	6.420x	|	7.30%	|	Baozun Inc. https://finance.yahoo.com/quote/BZUN?p=BZUN&.tsrc=fin-srch
# IQI	|	2061	|	7.038x	|	7.52%	|	Invesco Quality Municipal Income Trust Common Stock https://finance.yahoo.com/quote/IQI?p=IQI&.tsrc=fin-srch
# CRVL	|	2062	|	20.381x	|	21.49%	|	CorVel Corp. https://finance.yahoo.com/quote/CRVL?p=CRVL&.tsrc=fin-srch
# MOV	|	2065	|	7.925x	|	7.79%	|	Movado Group Inc. Common Stock https://finance.yahoo.com/quote/MOV?p=MOV&.tsrc=fin-srch
# SECO	|	2065	|	2.178x	|	6.29%	|	Secoo Holding Limited https://finance.yahoo.com/quote/SECO?p=SECO&.tsrc=fin-srch
# NEV	|	2067	|	8.808x	|	8.33%	|	Nuveen Enhanced Municipal Value Fund Common Shares of Beneficial Interest https://finance.yahoo.com/quote/NEV?p=NEV&.tsrc=fin-srch
# SSD	|	2067	|	21.504x	|	24.03%	|	Simpson Manufacturing Company, Inc. Common Stock https://finance.yahoo.com/quote/SSD?p=SSD&.tsrc=fin-srch
# DISCK	|	2072	|	7.256x	|	7.52%	|	Discovery, Inc. https://finance.yahoo.com/quote/DISCK?p=DISCK&.tsrc=fin-srch
# VKQ	|	2073	|	7.019x	|	7.38%	|	Invesco Municipal Trust Common Stock https://finance.yahoo.com/quote/VKQ?p=VKQ&.tsrc=fin-srch
# CATC	|	2073	|	13.378x	|	11.84%	|	Cambridge Bancorp https://finance.yahoo.com/quote/CATC?p=CATC&.tsrc=fin-srch
# FNB	|	2073	|	9.983x	|	8.91%	|	F.N.B. Corporation Common Stock https://finance.yahoo.com/quote/FNB?p=FNB&.tsrc=fin-srch
# NTRS	|	2075	|	14.527x	|	12.88%	|	Northern Trust Corporation https://finance.yahoo.com/quote/NTRS?p=NTRS&.tsrc=fin-srch
# NSP	|	2078	|	22.794x	|	27.86%	|	Insperity, Inc. Common Stock https://finance.yahoo.com/quote/NSP?p=NSP&.tsrc=fin-srch
# KELYA	|	2080	|	6.832x	|	7.29%	|	Kelly Services, Inc. https://finance.yahoo.com/quote/KELYA?p=KELYA&.tsrc=fin-srch
# TOWR	|	2081	|	12.393x	|	10.81%	|	Tower International, Inc. Common stock https://finance.yahoo.com/quote/TOWR?p=TOWR&.tsrc=fin-srch
# CHKP	|	2082	|	21.068x	|	22.03%	|	Check Point Software Technologies Ltd. https://finance.yahoo.com/quote/CHKP?p=CHKP&.tsrc=fin-srch
# AMAT	|	2083	|	21.660x	|	23.28%	|	Applied Materials, Inc. https://finance.yahoo.com/quote/AMAT?p=AMAT&.tsrc=fin-srch
# HSIC	|	2083	|	15.209x	|	13.31%	|	Henry Schein, Inc. https://finance.yahoo.com/quote/HSIC?p=HSIC&.tsrc=fin-srch
# FCAU	|	2084	|	3.132x	|	6.32%	|	Fiat Chrysler Automobiles N.V. Common Shares https://finance.yahoo.com/quote/FCAU?p=FCAU&.tsrc=fin-srch
# ...
# UTX	|	2899	|	24.028x	|	7.84%	|	United Technologies Corporation Common Stock https://finance.yahoo.com/quote/UTX?p=UTX&.tsrc=fin-srch
# APD	|	2902	|	32.387x	|	10.65%	|	Air Products and Chemicals, Inc. Common Stock https://finance.yahoo.com/quote/APD?p=APD&.tsrc=fin-srch
# WTRH	|	2904	|	24.407x	|	7.90%	|	Waitr Holdings Inc. https://finance.yahoo.com/quote/WTRH?p=WTRH&.tsrc=fin-srch
# HBMD	|	2908	|	19.914x	|	6.45%	|	Howard Bancorp, Inc. https://finance.yahoo.com/quote/HBMD?p=HBMD&.tsrc=fin-srch
# CBPO	|	2911	|	32.353x	|	10.53%	|	China Biologic Products Holdings, Inc. https://finance.yahoo.com/quote/CBPO?p=CBPO&.tsrc=fin-srch
# IEX	|	2912	|	37.329x	|	11.71%	|	IDEX Corporation Common Stock https://finance.yahoo.com/quote/IEX?p=IEX&.tsrc=fin-srch
# WKHS	|	2912	|	52.828x	|	14.90%	|	Workhorse Group, Inc. https://finance.yahoo.com/quote/WKHS?p=WKHS&.tsrc=fin-srch
# SYKE	|	2925	|	27.349x	|	8.77%	|	Sykes Enterprises, Incorporated https://finance.yahoo.com/quote/SYKE?p=SYKE&.tsrc=fin-srch
# WBC	|	2927	|	28.393x	|	9.03%	|	Wabco Holdings Inc. Common Stock https://finance.yahoo.com/quote/WBC?p=WBC&.tsrc=fin-srch
# RS	|	2927	|	20.231x	|	6.38%	|	Reliance Steel & Aluminum Co. Common Stock https://finance.yahoo.com/quote/RS?p=RS&.tsrc=fin-srch
# AZN	|	2927	|	24.435x	|	7.69%	|	Astrazeneca PLC Common Stock https://finance.yahoo.com/quote/AZN?p=AZN&.tsrc=fin-srch
# TDY	|	2929	|	34.453x	|	10.85%	|	Teledyne Technologies Incorporated Common Stock https://finance.yahoo.com/quote/TDY?p=TDY&.tsrc=fin-srch
# CORE	|	2930	|	21.886x	|	6.89%	|	Core-Mark Holding Company, Inc. https://finance.yahoo.com/quote/CORE?p=CORE&.tsrc=fin-srch
# PAHC	|	2931	|	27.727x	|	8.86%	|	Phibro Animal Health Corporation https://finance.yahoo.com/quote/PAHC?p=PAHC&.tsrc=fin-srch
# JBT	|	2933	|	34.082x	|	10.79%	|	John Bean Technologies Corporation Common Stock https://finance.yahoo.com/quote/JBT?p=JBT&.tsrc=fin-srch
# CSL	|	2936	|	24.676x	|	7.69%	|	Carlisle Companies Incorporated Common Stock https://finance.yahoo.com/quote/CSL?p=CSL&.tsrc=fin-srch
# FLIR	|	2937	|	32.233x	|	10.13%	|	FLIR Systems, Inc. https://finance.yahoo.com/quote/FLIR?p=FLIR&.tsrc=fin-srch
# KAI	|	2941	|	29.892x	|	9.29%	|	Kadant Inc Common Stock https://finance.yahoo.com/quote/KAI?p=KAI&.tsrc=fin-srch
# DLB	|	2941	|	29.105x	|	9.05%	|	Dolby Laboratories Common Stock https://finance.yahoo.com/quote/DLB?p=DLB&.tsrc=fin-srch
# PPG	|	2954	|	30.122x	|	9.25%	|	PPG Industries, Inc. Common Stock https://finance.yahoo.com/quote/PPG?p=PPG&.tsrc=fin-srch
# CIGI	|	2962	|	31.918x	|	9.68%	|	Colliers International Group Inc.  https://finance.yahoo.com/quote/CIGI?p=CIGI&.tsrc=fin-srch
# ARCO	|	2962	|	20.052x	|	6.06%	|	Arcos Dorados Holdings Inc. Class A Shares https://finance.yahoo.com/quote/ARCO?p=ARCO&.tsrc=fin-srch
# AEM	|	2971	|	30.798x	|	9.22%	|	Agnico Eagle Mines Limited Common Stock https://finance.yahoo.com/quote/AEM?p=AEM&.tsrc=fin-srch
# CTS	|	2972	|	28.754x	|	8.73%	|	CTS Corporation Common Stock https://finance.yahoo.com/quote/CTS?p=CTS&.tsrc=fin-srch
# THRM	|	2980	|	33.482x	|	9.98%	|	Gentherm Inc https://finance.yahoo.com/quote/THRM?p=THRM&.tsrc=fin-srch
# ROCK	|	2991	|	45.344x	|	11.84%	|	Gibraltar Industries, Inc. https://finance.yahoo.com/quote/ROCK?p=ROCK&.tsrc=fin-srch
# LOCO	|	3004	|	21.818x	|	6.28%	|	El Pollo Loco Holdings, Inc. https://finance.yahoo.com/quote/LOCO?p=LOCO&.tsrc=fin-srch
# MKC	|	3004	|	33.748x	|	9.74%	|	McCormick & Company, Incorporated Common Stock https://finance.yahoo.com/quote/MKC?p=MKC&.tsrc=fin-srch
# FCFS	|	3009	|	22.928x	|	6.63%	|	FirstCash, Inc. https://finance.yahoo.com/quote/FCFS?p=FCFS&.tsrc=fin-srch
# MDLZ	|	3013	|	22.535x	|	6.43%	|	Mondelez International, Inc. https://finance.yahoo.com/quote/MDLZ?p=MDLZ&.tsrc=fin-srch
# RPM	|	3022	|	31.680x	|	8.99%	|	RPM International Inc. Common Stock https://finance.yahoo.com/quote/RPM?p=RPM&.tsrc=fin-srch
# DLTR	|	3025	|	24.366x	|	6.85%	|	Dollar Tree, Inc. https://finance.yahoo.com/quote/DLTR?p=DLTR&.tsrc=fin-srch
# PZZA	|	3026	|	54.579x	|	12.91%	|	Papa John's International, Inc. https://finance.yahoo.com/quote/PZZA?p=PZZA&.tsrc=fin-srch
# EDU	|	3031	|	49.917x	|	11.96%	|	New Oriental Education & Technology Group, Inc. Sponsored ADR representing 1 Ordinary Share (Cayman Islands) https://finance.yahoo.com/quote/EDU?p=EDU&.tsrc=fin-srch
# NBIX	|	3037	|	24.682x	|	6.89%	|	Neurocrine Biosciences, Inc. https://finance.yahoo.com/quote/NBIX?p=NBIX&.tsrc=fin-srch
# MANT	|	3042	|	29.981x	|	8.39%	|	ManTech International Corporation https://finance.yahoo.com/quote/MANT?p=MANT&.tsrc=fin-srch
# MMI	|	3050	|	32.866x	|	9.01%	|	Marcus & Millichap, Inc. Common Stock https://finance.yahoo.com/quote/MMI?p=MMI&.tsrc=fin-srch
# SWK	|	3050	|	25.572x	|	6.98%	|	Stanley Black & Decker, Inc. Common Stock https://finance.yahoo.com/quote/SWK?p=SWK&.tsrc=fin-srch
# SNN	|	3051	|	35.962x	|	9.61%	|	Smith & Nephew SNATS, Inc. Common Stock https://finance.yahoo.com/quote/SNN?p=SNN&.tsrc=fin-srch
# CCMP	|	3056	|	29.006x	|	7.90%	|	CMC Materials, Inc. https://finance.yahoo.com/quote/CCMP?p=CCMP&.tsrc=fin-srch
# WY	|	3059	|	23.726x	|	6.39%	|	Weyerhaeuser Company Common Stock https://finance.yahoo.com/quote/WY?p=WY&.tsrc=fin-srch
# AKAM	|	3064	|	32.430x	|	8.79%	|	Akamai Technologies, Inc. https://finance.yahoo.com/quote/AKAM?p=AKAM&.tsrc=fin-srch
# CRL	|	3064	|	37.052x	|	9.61%	|	Charles River Laboratories International, Inc. Common Stock https://finance.yahoo.com/quote/CRL?p=CRL&.tsrc=fin-srch
# KSU	|	3067	|	31.450x	|	8.48%	|	Kansas City Southern Common Stock https://finance.yahoo.com/quote/KSU?p=KSU&.tsrc=fin-srch
# AVAV	|	3069	|	41.053x	|	10.17%	|	AeroVironment, Inc. https://finance.yahoo.com/quote/AVAV?p=AVAV&.tsrc=fin-srch
# ATEN	|	3075	|	43.350x	|	10.46%	|	A10 Networks, Inc. Common Stock https://finance.yahoo.com/quote/ATEN?p=ATEN&.tsrc=fin-srch
# HRC	|	3077	|	27.209x	|	7.29%	|	Hill https://finance.yahoo.com/quote/HRC?p=HRC&.tsrc=fin-srch
# NSSC	|	3078	|	57.021x	|	12.22%	|	NAPCO Security Technologies, Inc. https://finance.yahoo.com/quote/NSSC?p=NSSC&.tsrc=fin-srch
# ALRM	|	3080	|	59.402x	|	12.50%	|	Alarm.com Holdings, Inc. https://finance.yahoo.com/quote/ALRM?p=ALRM&.tsrc=fin-srch
# THO	|	3081	|	24.390x	|	6.41%	|	Thor Industries, Inc. Common Stock https://finance.yahoo.com/quote/THO?p=THO&.tsrc=fin-srch
# WLTW	|	3082	|	26.424x	|	6.97%	|	Willis Towers Watson Public Limited Company https://finance.yahoo.com/quote/WLTW?p=WLTW&.tsrc=fin-srch
# TRI	|	3083	|	26.016x	|	6.90%	|	Thomson Reuters Corp Ordinary Shares https://finance.yahoo.com/quote/TRI?p=TRI&.tsrc=fin-srch
# VFC	|	3083	|	33.969x	|	8.97%	|	V.F. Corporation Common Stock https://finance.yahoo.com/quote/VFC?p=VFC&.tsrc=fin-srch
# AJG	|	3084	|	26.921x	|	7.14%	|	Arthur J. Gallagher & Co. Common Stock https://finance.yahoo.com/quote/AJG?p=AJG&.tsrc=fin-srch
# CR	|	3086	|	24.376x	|	6.36%	|	Crane Company Common Stock https://finance.yahoo.com/quote/CR?p=CR&.tsrc=fin-srch
# JCOM	|	3086	|	31.547x	|	8.28%	|	j2 Global, Inc. https://finance.yahoo.com/quote/JCOM?p=JCOM&.tsrc=fin-srch
# BCPC	|	3088	|	40.944x	|	9.93%	|	Balchem Corporation https://finance.yahoo.com/quote/BCPC?p=BCPC&.tsrc=fin-srch
# BX	|	3102	|	44.795x	|	10.24%	|	The Blackstone Group L.P. Common Units Representing Limited Partnership Interests https://finance.yahoo.com/quote/BX?p=BX&.tsrc=fin-srch
# HUBG	|	3103	|	23.814x	|	6.10%	|	Hub Group, Inc. https://finance.yahoo.com/quote/HUBG?p=HUBG&.tsrc=fin-srch
# FORM	|	3105	|	47.382x	|	10.53%	|	FormFactor, Inc. https://finance.yahoo.com/quote/FORM?p=FORM&.tsrc=fin-srch
# DE	|	3105	|	29.074x	|	7.51%	|	Deere & Company Common Stock https://finance.yahoo.com/quote/DE?p=DE&.tsrc=fin-srch
# EFX	|	3111	|	41.170x	|	9.61%	|	Equifax, Inc. Common Stock https://finance.yahoo.com/quote/EFX?p=EFX&.tsrc=fin-srch
# ATR	|	3121	|	40.019x	|	9.38%	|	AptarGroup, Inc. Common Stock https://finance.yahoo.com/quote/ATR?p=ATR&.tsrc=fin-srch
# HEI	|	3124	|	53.037x	|	11.03%	|	Heico Corporation Common Stock https://finance.yahoo.com/quote/HEI?p=HEI&.tsrc=fin-srch
# SNPS	|	3126	|	51.755x	|	10.83%	|	Synopsys, Inc. https://finance.yahoo.com/quote/SNPS?p=SNPS&.tsrc=fin-srch
# CALX	|	3134	|	49.599x	|	10.51%	|	Calix, Inc Common Stock https://finance.yahoo.com/quote/CALX?p=CALX&.tsrc=fin-srch
# SAP	|	3135	|	47.088x	|	10.05%	|	SAP  SE ADS https://finance.yahoo.com/quote/SAP?p=SAP&.tsrc=fin-srch
# WPC	|	3136	|	24.934x	|	6.13%	|	W.P. Carey Inc. REIT https://finance.yahoo.com/quote/WPC?p=WPC&.tsrc=fin-srch
# RBC	|	3138	|	26.645x	|	6.64%	|	Regal Beloit Corporation Common Stock https://finance.yahoo.com/quote/RBC?p=RBC&.tsrc=fin-srch
# ICE	|	3140	|	29.159x	|	7.24%	|	Intercontinental Exchange Inc. Common Stock https://finance.yahoo.com/quote/ICE?p=ICE&.tsrc=fin-srch
# MCRI	|	3147	|	30.276x	|	7.45%	|	Monarch Casino & Resort, Inc. https://finance.yahoo.com/quote/MCRI?p=MCRI&.tsrc=fin-srch
# MSA	|	3148	|	50.547x	|	10.44%	|	MSA Safety Incorporated Common Stock https://finance.yahoo.com/quote/MSA?p=MSA&.tsrc=fin-srch
# A	|	3151	|	50.077x	|	10.32%	|	Agilent Technologies, Inc. Common Stock https://finance.yahoo.com/quote/A?p=A&.tsrc=fin-srch
# VSH	|	3153	|	25.215x	|	6.11%	|	Vishay Intertechnology, Inc. Common Stock https://finance.yahoo.com/quote/VSH?p=VSH&.tsrc=fin-srch
# EME	|	3156	|	36.661x	|	8.70%	|	EMCOR Group, Inc. Common Stock https://finance.yahoo.com/quote/EME?p=EME&.tsrc=fin-srch
# CME	|	3157	|	30.885x	|	7.47%	|	CME Group Inc. https://finance.yahoo.com/quote/CME?p=CME&.tsrc=fin-srch
# SPNS	|	3159	|	49.560x	|	10.10%	|	Sapiens International Corporation N.V. https://finance.yahoo.com/quote/SPNS?p=SPNS&.tsrc=fin-srch
# EGRX	|	3162	|	52.674x	|	10.54%	|	Eagle Pharmaceuticals, Inc. https://finance.yahoo.com/quote/EGRX?p=EGRX&.tsrc=fin-srch
# SON	|	3164	|	27.969x	|	6.79%	|	Sonoco Products Company Common Stock https://finance.yahoo.com/quote/SON?p=SON&.tsrc=fin-srch
# AET	|	3172	|	32.881x	|	7.81%	|	Aetna Inc. Common Stock https://finance.yahoo.com/quote/AET?p=AET&.tsrc=fin-srch
# PRAH	|	3181	|	40.345x	|	8.89%	|	PRA Health Sciences, Inc. https://finance.yahoo.com/quote/PRAH?p=PRAH&.tsrc=fin-srch
# DIOD	|	3183	|	36.648x	|	8.39%	|	Diodes Incorporated https://finance.yahoo.com/quote/DIOD?p=DIOD&.tsrc=fin-srch
# ASTE	|	3189	|	28.639x	|	6.74%	|	Astec Industries, Inc. https://finance.yahoo.com/quote/ASTE?p=ASTE&.tsrc=fin-srch
# WM	|	3190	|	31.454x	|	7.34%	|	Waste Management, Inc. Common Stock https://finance.yahoo.com/quote/WM?p=WM&.tsrc=fin-srch
# NSC	|	3193	|	30.316x	|	7.07%	|	Norfolk Southern Corporation Common Stock https://finance.yahoo.com/quote/NSC?p=NSC&.tsrc=fin-srch
# ICFI	|	3198	|	26.407x	|	6.02%	|	ICF International, Inc. https://finance.yahoo.com/quote/ICFI?p=ICFI&.tsrc=fin-srch
# KLIC	|	3224	|	31.822x	|	7.17%	|	Kulicke and Soffa Industries, Inc. https://finance.yahoo.com/quote/KLIC?p=KLIC&.tsrc=fin-srch
# BAX	|	3229	|	35.487x	|	7.74%	|	Baxter International Inc. Common Stock https://finance.yahoo.com/quote/BAX?p=BAX&.tsrc=fin-srch
# CAT	|	3231	|	34.250x	|	7.59%	|	Caterpillar, Inc. Common Stock https://finance.yahoo.com/quote/CAT?p=CAT&.tsrc=fin-srch
# IPAR	|	3234	|	51.309x	|	9.45%	|	Inter Parfums, Inc. https://finance.yahoo.com/quote/IPAR?p=IPAR&.tsrc=fin-srch
# BRKR	|	3234	|	56.936x	|	10.02%	|	Bruker Corporation https://finance.yahoo.com/quote/BRKR?p=BRKR&.tsrc=fin-srch
# FWRD	|	3241	|	37.695x	|	7.92%	|	Forward Air Corporation https://finance.yahoo.com/quote/FWRD?p=FWRD&.tsrc=fin-srch
# MCK	|	3249	|	28.407x	|	6.14%	|	McKesson Corporation Common Stock https://finance.yahoo.com/quote/MCK?p=MCK&.tsrc=fin-srch
# FOXF	|	3250	|	51.619x	|	9.32%	|	Fox Factory Holding Corp. https://finance.yahoo.com/quote/FOXF?p=FOXF&.tsrc=fin-srch
# LHCG	|	3253	|	55.506x	|	9.66%	|	LHC Group https://finance.yahoo.com/quote/LHCG?p=LHCG&.tsrc=fin-srch
# USG	|	3261	|	30.884x	|	6.64%	|	USG Corporation Common Stock https://finance.yahoo.com/quote/USG?p=USG&.tsrc=fin-srch
# TR	|	3263	|	43.281x	|	8.34%	|	Tootsie Roll Industries, Inc. Common Stock https://finance.yahoo.com/quote/TR?p=TR&.tsrc=fin-srch
# PHG	|	3265	|	37.023x	|	7.63%	|	Koninklijke Philips N.V. NY Registry Shares https://finance.yahoo.com/quote/PHG?p=PHG&.tsrc=fin-srch
# EXR	|	3266	|	30.280x	|	6.43%	|	Extra Space Storage Inc Common Stock https://finance.yahoo.com/quote/EXR?p=EXR&.tsrc=fin-srch
# HZNP	|	3266	|	38.160x	|	7.73%	|	Horizon Therapeutics Public Limited Company https://finance.yahoo.com/quote/HZNP?p=HZNP&.tsrc=fin-srch
# QNST	|	3276	|	32.565x	|	6.86%	|	QuinStreet, Inc. https://finance.yahoo.com/quote/QNST?p=QNST&.tsrc=fin-srch
# VMC	|	3287	|	33.627x	|	6.99%	|	Vulcan Materials Company (Holding Company) Common Stock https://finance.yahoo.com/quote/VMC?p=VMC&.tsrc=fin-srch
# OSTK	|	3289	|	57.114x	|	9.38%	|	Overstock.com, Inc. https://finance.yahoo.com/quote/OSTK?p=OSTK&.tsrc=fin-srch
# ABB	|	3292	|	34.982x	|	7.21%	|	ABB Ltd Common Stock https://finance.yahoo.com/quote/ABB?p=ABB&.tsrc=fin-srch
# AWR	|	3292	|	32.969x	|	6.85%	|	American States Water Company Common Stock https://finance.yahoo.com/quote/AWR?p=AWR&.tsrc=fin-srch
# GFI	|	3308	|	33.024x	|	6.74%	|	Gold Fields Limited American Depositary Shares https://finance.yahoo.com/quote/GFI?p=GFI&.tsrc=fin-srch
# AMOT	|	3313	|	31.492x	|	6.33%	|	Allied Motion Technologies, Inc. https://finance.yahoo.com/quote/AMOT?p=AMOT&.tsrc=fin-srch
# SXI	|	3319	|	33.215x	|	6.69%	|	Standex International Corporation Common Stock https://finance.yahoo.com/quote/SXI?p=SXI&.tsrc=fin-srch
# VNDA	|	3320	|	33.591x	|	6.77%	|	Vanda Pharmaceuticals Inc. https://finance.yahoo.com/quote/VNDA?p=VNDA&.tsrc=fin-srch
# KEM	|	3330	|	38.781x	|	7.32%	|	Kemet Corporation New Common Stock https://finance.yahoo.com/quote/KEM?p=KEM&.tsrc=fin-srch
# ABT	|	3331	|	48.700x	|	8.19%	|	Abbott Laboratories Common Stock https://finance.yahoo.com/quote/ABT?p=ABT&.tsrc=fin-srch
# ETN	|	3352	|	34.976x	|	6.73%	|	Eaton Corporation, PLC Ordinary Shares https://finance.yahoo.com/quote/ETN?p=ETN&.tsrc=fin-srch
# NICE	|	3360	|	57.902x	|	8.78%	|	NICE Ltd https://finance.yahoo.com/quote/NICE?p=NICE&.tsrc=fin-srch
# TRMB	|	3391	|	42.250x	|	7.10%	|	Trimble Inc. https://finance.yahoo.com/quote/TRMB?p=TRMB&.tsrc=fin-srch
# RGLD	|	3421	|	44.880x	|	7.07%	|	Royal Gold, Inc. https://finance.yahoo.com/quote/RGLD?p=RGLD&.tsrc=fin-srch
# HMSY	|	3427	|	46.420x	|	7.11%	|	HMS Holdings Corp https://finance.yahoo.com/quote/HMSY?p=HMSY&.tsrc=fin-srch
# ERII	|	3427	|	51.816x	|	7.62%	|	Energy Recovery, Inc. https://finance.yahoo.com/quote/ERII?p=ERII&.tsrc=fin-srch
# IT	|	3437	|	51.150x	|	7.47%	|	Gartner, Inc. Common Stock https://finance.yahoo.com/quote/IT?p=IT&.tsrc=fin-srch
# GMED	|	3444	|	59.799x	|	8.08%	|	Globus Medical, Inc. Class A Common Stock https://finance.yahoo.com/quote/GMED?p=GMED&.tsrc=fin-srch
# SYK	|	3447	|	42.415x	|	6.67%	|	Stryker Corporation Common Stock https://finance.yahoo.com/quote/SYK?p=SYK&.tsrc=fin-srch
# ADI	|	3457	|	42.072x	|	6.52%	|	Analog Devices, Inc. https://finance.yahoo.com/quote/ADI?p=ADI&.tsrc=fin-srch
# EV	|	3467	|	53.006x	|	7.38%	|	Eaton Vance Corporation Common Stock https://finance.yahoo.com/quote/EV?p=EV&.tsrc=fin-srch
# HMST	|	3504	|	47.344x	|	6.54%	|	HomeStreet, Inc. https://finance.yahoo.com/quote/HMST?p=HMST&.tsrc=fin-srch
# KNSL	|	3504	|	47.344x	|	6.57%	|	Kinsale Capital Group, Inc. https://finance.yahoo.com/quote/KNSL?p=KNSL&.tsrc=fin-srch
# LFUS	|	3549	|	51.126x	|	6.52%	|	Littelfuse, Inc. https://finance.yahoo.com/quote/LFUS?p=LFUS&.tsrc=fin-srch
# MRCY	|	3552	|	49.275x	|	6.33%	|	Mercury Systems Inc https://finance.yahoo.com/quote/MRCY?p=MRCY&.tsrc=fin-srch
# ICUI	|	3563	|	49.212x	|	6.22%	|	ICU Medical, Inc. https://finance.yahoo.com/quote/ICUI?p=ICUI&.tsrc=fin-srch
# ELS	|	3576	|	48.186x	|	6.05%	|	Equity Lifestyle Properties, Inc. Common Stock https://finance.yahoo.com/quote/ELS?p=ELS&.tsrc=fin-srch
# TFX	|	3578	|	52.311x	|	6.40%	|	Teleflex Incorporated Common Stock https://finance.yahoo.com/quote/TFX?p=TFX&.tsrc=fin-srch
# RMAX	|	3608	|	58.843x	|	6.62%	|	RE/MAX Holdings, Inc. Class A Common Stock https://finance.yahoo.com/quote/RMAX?p=RMAX&.tsrc=fin-srch
# COLM	|	3633	|	53.746x	|	6.11%	|	Columbia Sportswear Company https://finance.yahoo.com/quote/COLM?p=COLM&.tsrc=fin-srch
# PRFT	|	3651	|	57.527x	|	6.14%	|	Perficient, Inc. https://finance.yahoo.com/quote/PRFT?p=PRFT&.tsrc=fin-srch

# %% [markdown]
# ## Generate & export a .csv file for further analysis

# %%
with open('value_stock_analysis.csv', mode='w', newline='') as csv_file:
    fieldnames = ['name', 'pe', 'roic', 'pe_rank', 'roic_rank', 'rank', 'Full Name', 'Website']
    writer = csv.DictWriter(csv_file, fieldnames=fieldnames)
    
    writer.writeheader()
    for row in stockdat:
        writer.writerow(row)
