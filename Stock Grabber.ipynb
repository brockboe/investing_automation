# %% [markdown]
# # Value Investing Automation
#
# ## 1. Load Libraries

# %%
import csv
import requests
import numpy as np
from time import sleep

# %% [markdown]
# ## 2. Set some initial parameters

# %%
# Minimum market capitalization, to weed out small-cap stocks
min_cap = 300000000
# API key required to access teh financial modeling prep services
api_key = 'api key here'

# %% [markdown]
# ## 3. Grab a list of NYSE stock tickers
#
# Grabbed from a generic .csv file containing almost all stocks listed on the NYSE

# %%
stocks_raw = []

# %%
ticker_to_name = {}

with open("nyse-listed.csv", mode='r') as csv_file:
    # open the .csv and iterate through the rows
    csv_reader = csv.DictReader(csv_file)
    line = 0
    for row in csv_reader:
        line += 1
        if '$' in row['ACT Symbol']:
            # '$' character is found in some weird listings in the .csv file.
            # Just ignore these listings
            continue
        if line == 0:
            # first (zeroeth) line is just column labels, ignore them
            continue
        
        # put the ticker into a list if it matches the above criteria.
        # Called an 'ACT Symbol' for some reason in this .csv
        stocks_raw.append(row['ACT Symbol'])
        ticker_to_name[row['ACT Symbol']] = row['Company Name']

# %% [markdown]
# ## 4. Define functions to grab the market capitalization (CAP), return on invested capital (ROIC), and price to earnings ratio (PE)

# %%
def getCAP(stock, api_key):
    try:
        # Try to grab the information directly
        evalues = requests.get(f"https://financialmodelingprep.com/api/v3/enterprise-values/{stock}?limit=1&apikey={api_key}").json()
    except:
        # If attempt fails, it's most likely we've exceeded the number of API calls allowed
        # within a specific amount of time. Wait a few minutes and then try again.
        print("getCAP: too many requests! Pausing for 5 minutes")
        sleep(300)
        evalues = requests.get(f"https://financialmodelingprep.com/api/v3/enterprise-values/{stock}?limit=1&apikey={api_key}").json()
    try:
        # try to return the CAP. It is sometimes possible that the CAP is not available
        # for a given ticker. If that is the case, return Nothing
        return evalues[0]['marketCapitalization']
    except:
        return None

# ============================= Same logic applies on lower 2 functions ======================================== #
    
def getROIC(stock, api_key):
    try:
        key_metrics = requests.get(f"https://financialmodelingprep.com/api/v3/key-metrics-ttm/{stock}?limit=1&apikey={api_key}").json()
    except:
        print("getROIC: too many requests! Pausing for 5 minutes")
        sleep(300)
        key_metrics = requests.get(f"https://financialmodelingprep.com/api/v3/key-metrics-ttm/{stock}?limit=1&apikey={api_key}").json()
    try:
        return key_metrics[0]['roicTTM']
    except:
        return None
    

def getPE(stock, api_key):
    try:
        ratios = requests.get(f"https://financialmodelingprep.com/api/v3/ratios-ttm/{stock}?limit=1&apikey={api_key}").json()
    except:
        print("getPE: too many requests! Pausing for 5 minutes")
        sleep(300)
        ratios = requests.get(f"https://financialmodelingprep.com/api/v3/ratios-ttm/{stock}?limit=1&apikey={api_key}").json()
    try:
        return ratios[0]['peRatioTTM']
    except:
        return None

# Perform some tests to ensure that the above functions work,
# grab some basic information on Apple Inc.
print("(Example) Apple market cap:\t" + str(getCAP('AAPL', api_key)))
print("(Example) Apple ROIC:\t\t" + str(getROIC('AAPL', api_key)))
print("(Example) Apple PE:\t\t" + str(getPE('AAPL', api_key)))
# Out:
# (Example) Apple market cap:	1996361343006.3572
# (Example) Apple ROIC:		0.33740921790861533
# (Example) Apple PE:		31.782818357891443

# %% [markdown]
# ## 5. Remove the tickers with market caps below the pre-specified threshold

# %%
stocks = []
for s in stocks_raw:
    # Grab the market cap for a ticker
    cap = getCAP(s, api_key)
    
    # If the market capitalization cannot be found, don't add it. Just skip it.
    if not cap:
        continue
        
    # If the ticker's market cap is above the threshold, add it.
    if cap >= min_cap:
        stocks.append(s)

# %% [markdown]
# ## 6. Grab the PE & ROIC for remaining tickers

# %%
stockdat = []
for s in stocks:
    sdat = {}
    roic = getROIC(s, api_key)    # Grab the ROIC
    pe = getPE(s, api_key)        # Grab the PE ratio
    
    # If either the ROIC or PE ratio cannot be found for a
    # ticker, ignore it.
    if (roic is None) or (pe is None):
        continue
        
    # Add the pe, roic, and name to a dictionary object and
    # append it to a list of stock data
    sdat['pe'] = pe
    sdat['roic'] = roic
    sdat['name'] = s
    
    stockdat.append(sdat)
# Out:
# getPE: too many requests! Pausing for 5 minutes

# %% [markdown]
# ## 7. Sort the tickers by general rank
#
# Set some initial parameters to further sort results

# %%
pe_min = 0.0             # minimum price to earnings ratio
pe_max = 60.0            # maximum price to earnings ratio

roic_min = 0.06          # minimum ROIC
roic_max = 9999999999    # maximum ROIC

# %%
# Generate an argsort list to organize the PE ratios from lowest to highest
pe_list_argsort = np.argsort(np.array([x['pe'] for x in stockdat]))

# Generate an argsort list to organize the ROIC from highest to lowest
roic_list_argsort = np.flip(np.argsort(np.array([x['roic'] for x in stockdat])))

# Attach the PE ratio & ROIC rankings to each ticker.
# Also calculate a "general" rank by adding each PE & ROIC
# ranking.
for i in range(len(stockdat)):
    stockdat[i]['pe_rank'] = pe_list_argsort[i]
    stockdat[i]['roic_rank'] = roic_list_argsort[i]
    stockdat[i]['rank'] = pe_list_argsort[i] + roic_list_argsort[i]
    
    stockdat[i]['Full Name'] = ticker_to_name[stockdat[i]['name']]
    stockdat[i]['Website'] =  f"https://finance.yahoo.com/quote/{sdat['name']}?p={sdat['name']}&.tsrc=fin-srch"

# Generate an argsort list to organize stock tickers by "general rank"
rank_argsort = np.argsort(np.array([x['rank'] for x in stockdat]))


# Print all stock tickers in order of "general" rank, assuming
# they're within the thresholds
print("Name \t|\t rank \t|\t PE \t|\t ROIC \t|\t Website")
print("=====================================================================================================")
for i in range(len(stockdat)):
    sdat = stockdat[rank_argsort[i]]
    if (sdat['pe'] <= pe_min) or (sdat['pe'] >= pe_max):
        continue
    if (sdat['roic'] <= roic_min) or (sdat['roic'] >= roic_max):
        continue
    print(str(sdat['name']) +
          "\t|\t" +
          str(sdat['rank']) +
          "\t|\t" +
          "{0:.3f}".format(sdat['pe']) +
          "x\t|\t" +
          "{0:.2%}".format(sdat['roic']) +
          "\t|\t" +
          ticker_to_name[sdat['name']] + " " +
          f"https://finance.yahoo.com/quote/{sdat['name']}?p={sdat['name']}&.tsrc=fin-srch")
# Out:
# Name 	|	 rank 	|	 PE 	|	 ROIC 	|	 Website
# =====================================================================================================
# ELS	|	100	|	48.550x	|	6.05%	|	Equity Lifestyle Properties, Inc. Common Stock https://finance.yahoo.com/quote/ELS?p=ELS&.tsrc=fin-srch
# MO	|	111	|	19.945x	|	17.97%	|	Altria Group, Inc. https://finance.yahoo.com/quote/MO?p=MO&.tsrc=fin-srch
# BAX	|	116	|	35.935x	|	7.74%	|	Baxter International Inc. Common Stock https://finance.yahoo.com/quote/BAX?p=BAX&.tsrc=fin-srch
# GGG	|	131	|	30.405x	|	22.48%	|	Graco Inc. Common Stock https://finance.yahoo.com/quote/GGG?p=GGG&.tsrc=fin-srch
# BTT	|	135	|	8.244x	|	8.48%	|	BlackRock Municipal Target Term Trust Inc. (The) Common Shares of Beneficial Interest https://finance.yahoo.com/quote/BTT?p=BTT&.tsrc=fin-srch
# NAC	|	144	|	5.945x	|	9.73%	|	Nuveen California Dividend Advantage Municipal Fund Common Stock https://finance.yahoo.com/quote/NAC?p=NAC&.tsrc=fin-srch
# DG	|	161	|	18.558x	|	16.12%	|	Dollar General Corporation Common Stock https://finance.yahoo.com/quote/DG?p=DG&.tsrc=fin-srch
# SYF	|	163	|	11.699x	|	9.79%	|	Synchrony Financial Common Stock https://finance.yahoo.com/quote/SYF?p=SYF&.tsrc=fin-srch
# BAH	|	178	|	19.788x	|	16.24%	|	Booz Allen Hamilton Holding Corporation Common Stock https://finance.yahoo.com/quote/BAH?p=BAH&.tsrc=fin-srch
# WM	|	202	|	33.874x	|	7.34%	|	Waste Management, Inc. Common Stock https://finance.yahoo.com/quote/WM?p=WM&.tsrc=fin-srch
# URI	|	249	|	25.192x	|	7.13%	|	United Rentals, Inc. Common Stock https://finance.yahoo.com/quote/URI?p=URI&.tsrc=fin-srch
# NUS	|	258	|	13.813x	|	18.12%	|	Nu Skin Enterprises, Inc. Common Stock https://finance.yahoo.com/quote/NUS?p=NUS&.tsrc=fin-srch
# MSI	|	265	|	31.998x	|	15.88%	|	Motorola Solutions, Inc. Common Stock https://finance.yahoo.com/quote/MSI?p=MSI&.tsrc=fin-srch
# KGC	|	281	|	7.754x	|	16.54%	|	Kinross Gold Corporation Common Stock https://finance.yahoo.com/quote/KGC?p=KGC&.tsrc=fin-srch
# ALLE	|	293	|	34.088x	|	14.34%	|	Allegion plc Ordinary Shares https://finance.yahoo.com/quote/ALLE?p=ALLE&.tsrc=fin-srch
# HLF	|	344	|	15.200x	|	26.50%	|	Herbalife Ltd. Common Stock https://finance.yahoo.com/quote/HLF?p=HLF&.tsrc=fin-srch
# PG	|	350	|	23.189x	|	19.39%	|	Procter & Gamble Company (The) Common Stock https://finance.yahoo.com/quote/PG?p=PG&.tsrc=fin-srch
# DKS	|	364	|	16.130x	|	10.35%	|	Dick's Sporting Goods Inc Common Stock https://finance.yahoo.com/quote/DKS?p=DKS&.tsrc=fin-srch
# MYE	|	379	|	18.479x	|	21.96%	|	Myers Industries, Inc. Common Stock https://finance.yahoo.com/quote/MYE?p=MYE&.tsrc=fin-srch
# DHT	|	399	|	2.953x	|	20.58%	|	DHT Holdings, Inc. https://finance.yahoo.com/quote/DHT?p=DHT&.tsrc=fin-srch
# GNRC	|	411	|	57.413x	|	17.20%	|	Generac Holdlings Inc. Common Stock https://finance.yahoo.com/quote/GNRC?p=GNRC&.tsrc=fin-srch
# SBH	|	424	|	20.044x	|	6.87%	|	Sally Beauty Holdings, Inc. (Name to be changed from Sally Holdings, Inc.) Common Stock https://finance.yahoo.com/quote/SBH?p=SBH&.tsrc=fin-srch
# MLM	|	425	|	29.400x	|	8.82%	|	Martin Marietta Materials, Inc. Common Stock https://finance.yahoo.com/quote/MLM?p=MLM&.tsrc=fin-srch
# PFSI	|	428	|	2.871x	|	7.38%	|	PennyMac Financial Services, Inc. Class A Common Stock https://finance.yahoo.com/quote/PFSI?p=PFSI&.tsrc=fin-srch
# EXR	|	431	|	34.977x	|	6.43%	|	Extra Space Storage Inc Common Stock https://finance.yahoo.com/quote/EXR?p=EXR&.tsrc=fin-srch
# DECK	|	437	|	24.249x	|	25.61%	|	Deckers Outdoor Corporation Common Stock https://finance.yahoo.com/quote/DECK?p=DECK&.tsrc=fin-srch
# NEU	|	440	|	16.110x	|	20.43%	|	NewMarket Corp Common Stock https://finance.yahoo.com/quote/NEU?p=NEU&.tsrc=fin-srch
# MKC	|	455	|	30.568x	|	9.74%	|	McCormick & Company, Incorporated Common Stock https://finance.yahoo.com/quote/MKC?p=MKC&.tsrc=fin-srch
# TER	|	455	|	23.856x	|	30.53%	|	Teradyne, Inc. Common Stock https://finance.yahoo.com/quote/TER?p=TER&.tsrc=fin-srch
# FENG	|	457	|	1.253x	|	33.67%	|	Phoenix New Media Limited American Depositary Shares, each representing 8 Class A ordinary shares. https://finance.yahoo.com/quote/FENG?p=FENG&.tsrc=fin-srch
# TKR	|	474	|	20.917x	|	9.44%	|	Timken Company (The) Common Stock https://finance.yahoo.com/quote/TKR?p=TKR&.tsrc=fin-srch
# SNX	|	491	|	9.475x	|	8.98%	|	Synnex Corporation Common Stock https://finance.yahoo.com/quote/SNX?p=SNX&.tsrc=fin-srch
# AMTD	|	505	|	11.123x	|	19.42%	|	TD Ameritrade Holding Corporation Common Stock https://finance.yahoo.com/quote/AMTD?p=AMTD&.tsrc=fin-srch
# EXP	|	505	|	14.789x	|	15.94%	|	Eagle Materials Inc Common Stock https://finance.yahoo.com/quote/EXP?p=EXP&.tsrc=fin-srch
# ORCL	|	512	|	19.415x	|	13.92%	|	Oracle Corporation Common Stock https://finance.yahoo.com/quote/ORCL?p=ORCL&.tsrc=fin-srch
# CACI	|	521	|	16.171x	|	9.45%	|	CACI International, Inc. Class A Common Stock https://finance.yahoo.com/quote/CACI?p=CACI&.tsrc=fin-srch
# NSP	|	531	|	26.037x	|	27.86%	|	Insperity, Inc. Common Stock https://finance.yahoo.com/quote/NSP?p=NSP&.tsrc=fin-srch
# CMC	|	547	|	12.602x	|	10.17%	|	Commercial Metals Company Common Stock https://finance.yahoo.com/quote/CMC?p=CMC&.tsrc=fin-srch
# PSB	|	550	|	22.306x	|	10.19%	|	PS Business Parks, Inc. Common Stock https://finance.yahoo.com/quote/PSB?p=PSB&.tsrc=fin-srch
# ABT	|	550	|	45.662x	|	8.19%	|	Abbott Laboratories Common Stock https://finance.yahoo.com/quote/ABT?p=ABT&.tsrc=fin-srch
# WWE	|	558	|	34.043x	|	21.36%	|	World Wrestling Entertainment, Inc. Class A Common Stock https://finance.yahoo.com/quote/WWE?p=WWE&.tsrc=fin-srch
# SEE	|	571	|	14.383x	|	13.28%	|	Sealed Air Corporation Common Stock https://finance.yahoo.com/quote/SEE?p=SEE&.tsrc=fin-srch
# CLW	|	586	|	8.612x	|	6.31%	|	Clearwater Paper Corporation Common Stock https://finance.yahoo.com/quote/CLW?p=CLW&.tsrc=fin-srch
# WNS	|	586	|	35.689x	|	14.67%	|	WNS (Holdings) Limited Sponsored ADR (Jersey) https://finance.yahoo.com/quote/WNS?p=WNS&.tsrc=fin-srch
# LAZ	|	586	|	11.525x	|	10.53%	|	Lazard LTD. Lazard, LTD. Class A Common Stock https://finance.yahoo.com/quote/LAZ?p=LAZ&.tsrc=fin-srch
# WPC	|	590	|	25.734x	|	6.13%	|	W.P. Carey Inc. REIT https://finance.yahoo.com/quote/WPC?p=WPC&.tsrc=fin-srch
# K	|	595	|	8.549x	|	30.14%	|	Kellogg Company Common Stock https://finance.yahoo.com/quote/K?p=K&.tsrc=fin-srch
# NSH	|	603	|	5.537x	|	36.19%	|	Nustar GP Holdings, LLC Units https://finance.yahoo.com/quote/NSH?p=NSH&.tsrc=fin-srch
# RYAM	|	603	|	0.484x	|	60.42%	|	Rayonier Advanced Materials Inc. Common Stock https://finance.yahoo.com/quote/RYAM?p=RYAM&.tsrc=fin-srch
# RY	|	613	|	11.574x	|	14.70%	|	Royal Bank Of Canada Common Stock https://finance.yahoo.com/quote/RY?p=RY&.tsrc=fin-srch
# KAI	|	623	|	21.396x	|	15.99%	|	Kadant Inc Common Stock https://finance.yahoo.com/quote/KAI?p=KAI&.tsrc=fin-srch
# FMS	|	638	|	16.705x	|	7.73%	|	Fresenius Medical Care AG Common Stock https://finance.yahoo.com/quote/FMS?p=FMS&.tsrc=fin-srch
# TGT	|	645	|	12.129x	|	26.61%	|	Target Corporation Common Stock https://finance.yahoo.com/quote/TGT?p=TGT&.tsrc=fin-srch
# EPD	|	647	|	13.459x	|	6.82%	|	Enterprise Products Partners L.P. Common Stock https://finance.yahoo.com/quote/EPD?p=EPD&.tsrc=fin-srch
# MOH	|	662	|	19.947x	|	21.04%	|	Molina Healthcare Inc Common Stock https://finance.yahoo.com/quote/MOH?p=MOH&.tsrc=fin-srch
# A	|	663	|	45.626x	|	11.71%	|	Agilent Technologies, Inc. Common Stock https://finance.yahoo.com/quote/A?p=A&.tsrc=fin-srch
# WDR	|	677	|	10.763x	|	27.95%	|	Waddell & Reed Financial, Inc. Common Stock https://finance.yahoo.com/quote/WDR?p=WDR&.tsrc=fin-srch
# LXFR	|	677	|	29.192x	|	9.61%	|	Luxfer Holdings PLC American Depositary Shares (each representing one https://finance.yahoo.com/quote/LXFR?p=LXFR&.tsrc=fin-srch
# FLT	|	680	|	34.320x	|	12.21%	|	FleetCor Technologies, Inc. Common Stock https://finance.yahoo.com/quote/FLT?p=FLT&.tsrc=fin-srch
# GHC	|	692	|	9.887x	|	7.41%	|	Graham Holdings Company Common Stock https://finance.yahoo.com/quote/GHC?p=GHC&.tsrc=fin-srch
# VGM	|	696	|	6.637x	|	8.57%	|	Invesco Trust for Investment Grade Municipals Common Stock (DE) https://finance.yahoo.com/quote/VGM?p=VGM&.tsrc=fin-srch
# ATHM	|	696	|	3.522x	|	18.77%	|	Autohome Inc. American Depositary Shares, each representing one class A ordinary share. https://finance.yahoo.com/quote/ATHM?p=ATHM&.tsrc=fin-srch
# HNI	|	706	|	35.530x	|	6.78%	|	HNI Corporation Common Stock https://finance.yahoo.com/quote/HNI?p=HNI&.tsrc=fin-srch
# TPX	|	709	|	13.949x	|	19.37%	|	Tempur Sealy International, Inc. Common Stock https://finance.yahoo.com/quote/TPX?p=TPX&.tsrc=fin-srch
# MUSA	|	710	|	9.669x	|	23.63%	|	Murphy USA Inc. Common Stock https://finance.yahoo.com/quote/MUSA?p=MUSA&.tsrc=fin-srch
# OIA	|	718	|	5.680x	|	13.41%	|	Invesco Municipal Income Opportunities Trust Common Stock https://finance.yahoo.com/quote/OIA?p=OIA&.tsrc=fin-srch
# IQI	|	723	|	6.061x	|	9.57%	|	Invesco Quality Municipal Income Trust Common Stock https://finance.yahoo.com/quote/IQI?p=IQI&.tsrc=fin-srch
# SGU	|	723	|	6.984x	|	17.81%	|	Star Gas Partners, L.P. Common Stock https://finance.yahoo.com/quote/SGU?p=SGU&.tsrc=fin-srch
# SCCO	|	724	|	38.404x	|	17.64%	|	Southern Copper Corporation Common Stock https://finance.yahoo.com/quote/SCCO?p=SCCO&.tsrc=fin-srch
# SHW	|	730	|	31.139x	|	15.94%	|	Sherwin https://finance.yahoo.com/quote/SHW?p=SHW&.tsrc=fin-srch
# UVE	|	731	|	26.182x	|	28.40%	|	UNIVERSAL INSURANCE HOLDINGS INC Common Stock https://finance.yahoo.com/quote/UVE?p=UVE&.tsrc=fin-srch
# UNP	|	734	|	26.934x	|	11.99%	|	Union Pacific Corporation Common Stock https://finance.yahoo.com/quote/UNP?p=UNP&.tsrc=fin-srch
# MSA	|	737	|	53.443x	|	10.44%	|	MSA Safety Incorporated Common Stock https://finance.yahoo.com/quote/MSA?p=MSA&.tsrc=fin-srch
# PNR	|	742	|	27.748x	|	12.62%	|	Pentair plc. Ordinary Share https://finance.yahoo.com/quote/PNR?p=PNR&.tsrc=fin-srch
# CCK	|	743	|	22.742x	|	7.46%	|	Crown Holdings, Inc. https://finance.yahoo.com/quote/CCK?p=CCK&.tsrc=fin-srch
# CSX	|	744	|	25.920x	|	9.60%	|	CSX Corporation Common Stock https://finance.yahoo.com/quote/CSX?p=CSX&.tsrc=fin-srch
# CO	|	745	|	1.184x	|	8.27%	|	China Cord Blood Corporation Common Stock https://finance.yahoo.com/quote/CO?p=CO&.tsrc=fin-srch
# PWR	|	751	|	27.618x	|	9.13%	|	Quanta Services, Inc. Common Stock https://finance.yahoo.com/quote/PWR?p=PWR&.tsrc=fin-srch
# MBT	|	752	|	0.123x	|	13.69%	|	Mobile TeleSystems OJSC https://finance.yahoo.com/quote/MBT?p=MBT&.tsrc=fin-srch
# EQC	|	753	|	7.045x	|	13.32%	|	Equity Commonwealth Common Shares of Beneficial Interest https://finance.yahoo.com/quote/EQC?p=EQC&.tsrc=fin-srch
# ALSN	|	756	|	15.823x	|	9.58%	|	Allison Transmission Holdings, Inc. Common Stock https://finance.yahoo.com/quote/ALSN?p=ALSN&.tsrc=fin-srch
# ECOM	|	761	|	36.651x	|	14.00%	|	ChannelAdvisor Corporation Common Stock https://finance.yahoo.com/quote/ECOM?p=ECOM&.tsrc=fin-srch
# KOP	|	765	|	6.388x	|	8.43%	|	Koppers Holdings Inc. Koppers Holdings Inc. Common Stock https://finance.yahoo.com/quote/KOP?p=KOP&.tsrc=fin-srch
# HZO	|	775	|	13.891x	|	18.00%	|	MarineMax, Inc. Common Stock https://finance.yahoo.com/quote/HZO?p=HZO&.tsrc=fin-srch
# SNA	|	779	|	9.697x	|	31.04%	|	Snap https://finance.yahoo.com/quote/SNA?p=SNA&.tsrc=fin-srch
# AVAL	|	780	|	0.003x	|	6.58%	|	Grupo Aval Acciones y Valores S.A. ADR (Each representing 20 preferred shares) https://finance.yahoo.com/quote/AVAL?p=AVAL&.tsrc=fin-srch
# SXT	|	781	|	15.497x	|	16.02%	|	Sensient Technologies Corporation Common Stock https://finance.yahoo.com/quote/SXT?p=SXT&.tsrc=fin-srch
# BRC	|	785	|	27.452x	|	13.78%	|	Brady Corporation Common Stock https://finance.yahoo.com/quote/BRC?p=BRC&.tsrc=fin-srch
# MMC	|	791	|	29.305x	|	10.54%	|	Marsh & McLennan Companies, Inc. Common Stock https://finance.yahoo.com/quote/MMC?p=MMC&.tsrc=fin-srch
# VCV	|	796	|	6.255x	|	9.65%	|	Invesco California Value Municipal Income Trust Common Stock https://finance.yahoo.com/quote/VCV?p=VCV&.tsrc=fin-srch
# PSXP	|	801	|	8.966x	|	12.24%	|	Phillips 66 Partners LP Common Units representing limited partner interest in the Partnership https://finance.yahoo.com/quote/PSXP?p=PSXP&.tsrc=fin-srch
# MHO	|	806	|	6.840x	|	12.62%	|	M/I Homes, Inc. Common Stock https://finance.yahoo.com/quote/MHO?p=MHO&.tsrc=fin-srch
# LTC	|	810	|	17.708x	|	6.71%	|	LTC Properties, Inc. Common Stock https://finance.yahoo.com/quote/LTC?p=LTC&.tsrc=fin-srch
# UHT	|	812	|	34.754x	|	6.60%	|	Universal Health Realty Income Trust Common Stock https://finance.yahoo.com/quote/UHT?p=UHT&.tsrc=fin-srch
# BX	|	815	|	48.715x	|	10.24%	|	The Blackstone Group L.P. Common Units Representing Limited Partnership Interests https://finance.yahoo.com/quote/BX?p=BX&.tsrc=fin-srch
# RBC	|	817	|	17.628x	|	11.45%	|	Regal Beloit Corporation Common Stock https://finance.yahoo.com/quote/RBC?p=RBC&.tsrc=fin-srch
# ATR	|	823	|	42.347x	|	9.38%	|	AptarGroup, Inc. Common Stock https://finance.yahoo.com/quote/ATR?p=ATR&.tsrc=fin-srch
# BABA	|	825	|	4.012x	|	13.44%	|	Alibaba Group Holding Limited American Depositary Shares each representing one Ordinary share https://finance.yahoo.com/quote/BABA?p=BABA&.tsrc=fin-srch
# SEM	|	828	|	17.464x	|	7.34%	|	Select Medical Holdings Corporation Common Stock https://finance.yahoo.com/quote/SEM?p=SEM&.tsrc=fin-srch
# PPG	|	834	|	33.271x	|	9.25%	|	PPG Industries, Inc. Common Stock https://finance.yahoo.com/quote/PPG?p=PPG&.tsrc=fin-srch
# WST	|	836	|	57.621x	|	17.51%	|	West Pharmaceutical Services, Inc. Common Stock https://finance.yahoo.com/quote/WST?p=WST&.tsrc=fin-srch
# CLX	|	840	|	19.332x	|	30.29%	|	Clorox Company (The) Common Stock https://finance.yahoo.com/quote/CLX?p=CLX&.tsrc=fin-srch
# EMD	|	845	|	10.103x	|	6.81%	|	Western Asset Emerging Markets Income Fund, Inc. Common Stock https://finance.yahoo.com/quote/EMD?p=EMD&.tsrc=fin-srch
# WSO	|	845	|	29.058x	|	23.83%	|	Watsco, Inc. Common Stock https://finance.yahoo.com/quote/WSO?p=WSO&.tsrc=fin-srch
# EFX	|	850	|	39.980x	|	9.61%	|	Equifax, Inc. Common Stock https://finance.yahoo.com/quote/EFX?p=EFX&.tsrc=fin-srch
# CR	|	851	|	29.299x	|	6.36%	|	Crane Company Common Stock https://finance.yahoo.com/quote/CR?p=CR&.tsrc=fin-srch
# NSC	|	852	|	32.937x	|	7.07%	|	Norfolk Southern Corporation Common Stock https://finance.yahoo.com/quote/NSC?p=NSC&.tsrc=fin-srch
# JKS	|	856	|	9.660x	|	8.34%	|	JinkoSolar Holding Company Limited American Depositary Shares (each representing 4 Common Shares) https://finance.yahoo.com/quote/JKS?p=JKS&.tsrc=fin-srch
# RH	|	857	|	43.604x	|	16.07%	|	Restoration Hardware Holdings Inc. Common Stock https://finance.yahoo.com/quote/RH?p=RH&.tsrc=fin-srch
# SJM	|	859	|	14.439x	|	9.19%	|	J.M. Smucker Company (The) New Common Stock https://finance.yahoo.com/quote/SJM?p=SJM&.tsrc=fin-srch
# FF	|	864	|	6.076x	|	20.15%	|	FutureFuel Corp.  Common shares https://finance.yahoo.com/quote/FF?p=FF&.tsrc=fin-srch
# TOL	|	864	|	15.387x	|	49.71%	|	Toll Brothers Inc. Common Stock https://finance.yahoo.com/quote/TOL?p=TOL&.tsrc=fin-srch
# IEX	|	865	|	40.361x	|	11.71%	|	IDEX Corporation Common Stock https://finance.yahoo.com/quote/IEX?p=IEX&.tsrc=fin-srch
# TGS	|	868	|	0.118x	|	8.13%	|	Transportadora de Gas del Sur SA TGS Common Stock https://finance.yahoo.com/quote/TGS?p=TGS&.tsrc=fin-srch
# FDS	|	874	|	31.185x	|	23.44%	|	FactSet Research Systems Inc. Common Stock https://finance.yahoo.com/quote/FDS?p=FDS&.tsrc=fin-srch
# CAG	|	881	|	16.094x	|	6.56%	|	ConAgra Foods, Inc. Common Stock https://finance.yahoo.com/quote/CAG?p=CAG&.tsrc=fin-srch
# HIW	|	883	|	12.920x	|	7.24%	|	Highwoods Properties, Inc. Common Stock https://finance.yahoo.com/quote/HIW?p=HIW&.tsrc=fin-srch
# NRK	|	888	|	5.383x	|	10.35%	|	Nuveen New York AMT https://finance.yahoo.com/quote/NRK?p=NRK&.tsrc=fin-srch
# RS	|	888	|	25.802x	|	6.38%	|	Reliance Steel & Aluminum Co. Common Stock https://finance.yahoo.com/quote/RS?p=RS&.tsrc=fin-srch
# RGR	|	892	|	12.754x	|	45.40%	|	Sturm, Ruger & Company, Inc. Common Stock https://finance.yahoo.com/quote/RGR?p=RGR&.tsrc=fin-srch
# BMA	|	893	|	0.027x	|	23.15%	|	Banco Macro S.A.  ADR (representing Ten Class B Common Shares) https://finance.yahoo.com/quote/BMA?p=BMA&.tsrc=fin-srch
# BCC	|	894	|	13.619x	|	19.86%	|	Boise Cascade, L.L.C. Common Stock https://finance.yahoo.com/quote/BCC?p=BCC&.tsrc=fin-srch
# BC	|	896	|	23.712x	|	15.14%	|	Brunswick Corporation Common Stock https://finance.yahoo.com/quote/BC?p=BC&.tsrc=fin-srch
# BG	|	902	|	9.859x	|	11.15%	|	Bunge Limited Bunge Limited https://finance.yahoo.com/quote/BG?p=BG&.tsrc=fin-srch
# GIS	|	906	|	14.066x	|	12.28%	|	General Mills, Inc. Common Stock https://finance.yahoo.com/quote/GIS?p=GIS&.tsrc=fin-srch
# CE	|	915	|	8.835x	|	25.19%	|	Celanese Corporation Celanese Corporation Series A Common Stock https://finance.yahoo.com/quote/CE?p=CE&.tsrc=fin-srch
# WSM	|	915	|	17.780x	|	24.45%	|	Williams https://finance.yahoo.com/quote/WSM?p=WSM&.tsrc=fin-srch
# HII	|	918	|	10.953x	|	13.66%	|	Huntington Ingalls Industries, Inc. Common Stock https://finance.yahoo.com/quote/HII?p=HII&.tsrc=fin-srch
# SHLX	|	926	|	9.905x	|	24.55%	|	Shell Midstream Partners, L.P. Common Units representing Limited Partner Interests https://finance.yahoo.com/quote/SHLX?p=SHLX&.tsrc=fin-srch
# SYK	|	929	|	46.074x	|	6.67%	|	Stryker Corporation Common Stock https://finance.yahoo.com/quote/SYK?p=SYK&.tsrc=fin-srch
# TPRE	|	935	|	2.438x	|	11.01%	|	Third Point Reinsurance Ltd. Common Shares https://finance.yahoo.com/quote/TPRE?p=TPRE&.tsrc=fin-srch
# CHE	|	936	|	21.814x	|	34.86%	|	Chemed Corp https://finance.yahoo.com/quote/CHE?p=CHE&.tsrc=fin-srch
# FL	|	936	|	17.692x	|	9.42%	|	Foot Locker, Inc. https://finance.yahoo.com/quote/FL?p=FL&.tsrc=fin-srch
# FIX	|	940	|	18.361x	|	17.99%	|	Comfort Systems USA, Inc. Common Stock https://finance.yahoo.com/quote/FIX?p=FIX&.tsrc=fin-srch
# HEI	|	941	|	54.440x	|	11.03%	|	Heico Corporation Common Stock https://finance.yahoo.com/quote/HEI?p=HEI&.tsrc=fin-srch
# ENVA	|	949	|	3.596x	|	21.98%	|	Enova International, Inc. Common Stock https://finance.yahoo.com/quote/ENVA?p=ENVA&.tsrc=fin-srch
# WMT	|	955	|	18.936x	|	16.49%	|	Wal https://finance.yahoo.com/quote/WMT?p=WMT&.tsrc=fin-srch
# MSM	|	960	|	22.190x	|	16.82%	|	MSC Industrial Direct Company, Inc. Common Stock https://finance.yahoo.com/quote/MSM?p=MSM&.tsrc=fin-srch
# BCE	|	962	|	15.825x	|	6.24%	|	BCE, Inc. Common Stock https://finance.yahoo.com/quote/BCE?p=BCE&.tsrc=fin-srch
# APH	|	964	|	15.443x	|	15.23%	|	Amphenol Corporation Common Stock https://finance.yahoo.com/quote/APH?p=APH&.tsrc=fin-srch
# LDOS	|	976	|	12.657x	|	15.38%	|	Leidos Holdings, Inc. Common Stock https://finance.yahoo.com/quote/LDOS?p=LDOS&.tsrc=fin-srch
# MDC	|	976	|	10.599x	|	14.44%	|	M.D.C. Holdings, Inc. Common Stock https://finance.yahoo.com/quote/MDC?p=MDC&.tsrc=fin-srch
# CCZ	|	981	|	20.403x	|	7.40%	|	Comcast Holdings ZONES https://finance.yahoo.com/quote/CCZ?p=CCZ&.tsrc=fin-srch
# RNR	|	982	|	12.107x	|	10.57%	|	RenaissanceRe Holdings Ltd. Common Stock https://finance.yahoo.com/quote/RNR?p=RNR&.tsrc=fin-srch
# SF	|	983	|	16.032x	|	10.06%	|	Stifel Financial Corporation Common Stock https://finance.yahoo.com/quote/SF?p=SF&.tsrc=fin-srch
# MTG	|	991	|	9.860x	|	7.87%	|	MGIC Investment Corporation Common Stock https://finance.yahoo.com/quote/MTG?p=MTG&.tsrc=fin-srch
# CRL	|	993	|	38.534x	|	9.61%	|	Charles River Laboratories International, Inc. Common Stock https://finance.yahoo.com/quote/CRL?p=CRL&.tsrc=fin-srch
# APD	|	994	|	32.186x	|	10.41%	|	Air Products and Chemicals, Inc. Common Stock https://finance.yahoo.com/quote/APD?p=APD&.tsrc=fin-srch
# LH	|	995	|	14.838x	|	13.06%	|	Laboratory Corporation of America Holdings Common Stock https://finance.yahoo.com/quote/LH?p=LH&.tsrc=fin-srch
# EBF	|	999	|	20.008x	|	11.23%	|	Ennis, Inc. Common Stock https://finance.yahoo.com/quote/EBF?p=EBF&.tsrc=fin-srch
# BGS	|	1001	|	8.102x	|	9.51%	|	B&G Foods, Inc. B&G Foods, Inc. Common Stock https://finance.yahoo.com/quote/BGS?p=BGS&.tsrc=fin-srch
# STZ	|	1002	|	21.719x	|	9.95%	|	Constellation Brands, Inc. Common Stock https://finance.yahoo.com/quote/STZ?p=STZ&.tsrc=fin-srch
# BRO	|	1003	|	26.520x	|	9.44%	|	Brown & Brown, Inc. Common Stock https://finance.yahoo.com/quote/BRO?p=BRO&.tsrc=fin-srch
# CP	|	1003	|	20.647x	|	15.26%	|	Canadian Pacific Railway Limited Common Stock https://finance.yahoo.com/quote/CP?p=CP&.tsrc=fin-srch
# DCI	|	1009	|	29.733x	|	18.11%	|	Donaldson Company, Inc. Common Stock https://finance.yahoo.com/quote/DCI?p=DCI&.tsrc=fin-srch
# EVN	|	1010	|	8.906x	|	7.04%	|	Eaton Vance Municipal Income Trust Common Stock https://finance.yahoo.com/quote/EVN?p=EVN&.tsrc=fin-srch
# SVM	|	1013	|	21.617x	|	11.86%	|	Silvercorp Metals Inc Ordinary Shares (Canada) https://finance.yahoo.com/quote/SVM?p=SVM&.tsrc=fin-srch
# AZO	|	1015	|	16.410x	|	25.98%	|	AutoZone, Inc. Common Stock https://finance.yahoo.com/quote/AZO?p=AZO&.tsrc=fin-srch
# LEG	|	1020	|	26.963x	|	8.56%	|	Leggett & Platt, Incorporated Common Stock https://finance.yahoo.com/quote/LEG?p=LEG&.tsrc=fin-srch
# MTH	|	1023	|	8.057x	|	15.73%	|	Meritage Homes Corporation Common Stock https://finance.yahoo.com/quote/MTH?p=MTH&.tsrc=fin-srch
# EMR	|	1024	|	26.369x	|	14.30%	|	Emerson Electric Company Common Stock https://finance.yahoo.com/quote/EMR?p=EMR&.tsrc=fin-srch
# IIM	|	1028	|	5.682x	|	10.12%	|	Invesco Value Municipal Income Trust Common Stock https://finance.yahoo.com/quote/IIM?p=IIM&.tsrc=fin-srch
# KMB	|	1028	|	19.160x	|	26.44%	|	Kimberly https://finance.yahoo.com/quote/KMB?p=KMB&.tsrc=fin-srch
# PEP	|	1029	|	25.881x	|	13.04%	|	Pepsico, Inc. Common Stock https://finance.yahoo.com/quote/PEP?p=PEP&.tsrc=fin-srch
# VKQ	|	1035	|	6.308x	|	9.19%	|	Invesco Municipal Trust Common Stock https://finance.yahoo.com/quote/VKQ?p=VKQ&.tsrc=fin-srch
# ARW	|	1037	|	13.558x	|	9.58%	|	Arrow Electronics, Inc. Common Stock https://finance.yahoo.com/quote/ARW?p=ARW&.tsrc=fin-srch
# MLR	|	1045	|	17.102x	|	13.24%	|	Miller Industries, Inc. Common Stock https://finance.yahoo.com/quote/MLR?p=MLR&.tsrc=fin-srch
# MMM	|	1053	|	19.739x	|	17.03%	|	3M Company Common Stock https://finance.yahoo.com/quote/MMM?p=MMM&.tsrc=fin-srch
# TSN	|	1054	|	13.097x	|	8.69%	|	Tyson Foods, Inc. Common Stock https://finance.yahoo.com/quote/TSN?p=TSN&.tsrc=fin-srch
# STL	|	1056	|	15.961x	|	6.43%	|	Sterling Bancorp https://finance.yahoo.com/quote/STL?p=STL&.tsrc=fin-srch
# TTC	|	1060	|	29.590x	|	22.22%	|	Toro Company (The) Common Stock https://finance.yahoo.com/quote/TTC?p=TTC&.tsrc=fin-srch
# CAPL	|	1067	|	6.547x	|	11.47%	|	CrossAmerica Partners LP Common Units representing limited partner interests https://finance.yahoo.com/quote/CAPL?p=CAPL&.tsrc=fin-srch
# AN	|	1068	|	19.838x	|	9.61%	|	AutoNation, Inc. Common Stock https://finance.yahoo.com/quote/AN?p=AN&.tsrc=fin-srch
# DAR	|	1076	|	22.527x	|	16648.70%	|	Darling Ingredients Inc. Common Stock https://finance.yahoo.com/quote/DAR?p=DAR&.tsrc=fin-srch
# LEN	|	1076	|	11.497x	|	11.08%	|	Lennar Corporation Class A Common Stock https://finance.yahoo.com/quote/LEN?p=LEN&.tsrc=fin-srch
# NOAH	|	1097	|	3.095x	|	13.71%	|	Noah Holdings Limited https://finance.yahoo.com/quote/NOAH?p=NOAH&.tsrc=fin-srch
# SSTK	|	1097	|	45.680x	|	18.94%	|	Shutterstock, Inc. Common Stock https://finance.yahoo.com/quote/SSTK?p=SSTK&.tsrc=fin-srch
# NOC	|	1099	|	15.630x	|	10.69%	|	Northrop Grumman Corporation Common Stock https://finance.yahoo.com/quote/NOC?p=NOC&.tsrc=fin-srch
# FLO	|	1105	|	19.774x	|	11.59%	|	Flowers Foods, Inc. Common Stock https://finance.yahoo.com/quote/FLO?p=FLO&.tsrc=fin-srch
# RBA	|	1108	|	35.616x	|	12.84%	|	Ritchie Bros. Auctioneers Incorporated Common Stock https://finance.yahoo.com/quote/RBA?p=RBA&.tsrc=fin-srch
# NBB	|	1109	|	13.488x	|	7.85%	|	Nuveen Build America Bond Fund Common Shares of Beneficial Interest https://finance.yahoo.com/quote/NBB?p=NBB&.tsrc=fin-srch
# UHS	|	1115	|	11.972x	|	11.39%	|	Universal Health Services, Inc. Common Stock https://finance.yahoo.com/quote/UHS?p=UHS&.tsrc=fin-srch
# MCD	|	1128	|	33.718x	|	13.22%	|	McDonald's Corporation Common Stock https://finance.yahoo.com/quote/MCD?p=MCD&.tsrc=fin-srch
# SCU	|	1132	|	2.821x	|	21.53%	|	Scana Corporation SCANA CORPORATION 2009 Series A 7.70% Enhanced Junior Subordinated Notes https://finance.yahoo.com/quote/SCU?p=SCU&.tsrc=fin-srch
# BR	|	1133	|	32.185x	|	16.12%	|	Broadridge Financial Solutions, Inc.Common Stock https://finance.yahoo.com/quote/BR?p=BR&.tsrc=fin-srch
# HSY	|	1134	|	24.866x	|	20.65%	|	The Hershey Company Common Stock https://finance.yahoo.com/quote/HSY?p=HSY&.tsrc=fin-srch
# NYCB	|	1135	|	14.305x	|	7.07%	|	New York Community Bancorp, Inc. Common Stock https://finance.yahoo.com/quote/NYCB?p=NYCB&.tsrc=fin-srch
# LXP	|	1136	|	11.077x	|	8.18%	|	Lexington Realty Trust Common Stock https://finance.yahoo.com/quote/LXP?p=LXP&.tsrc=fin-srch
# BZH	|	1137	|	12.899x	|	11.59%	|	Beazer Homes USA, Inc. Common Stock https://finance.yahoo.com/quote/BZH?p=BZH&.tsrc=fin-srch
# BBY	|	1141	|	16.223x	|	27.87%	|	Best Buy Co., Inc. Common Stock https://finance.yahoo.com/quote/BBY?p=BBY&.tsrc=fin-srch
# ASGN	|	1141	|	25.429x	|	9.46%	|	On Assignment, Inc. Common Stock https://finance.yahoo.com/quote/ASGN?p=ASGN&.tsrc=fin-srch
# NX	|	1143	|	19.077x	|	10.50%	|	Quanex Building Products Corporation Common Stock https://finance.yahoo.com/quote/NX?p=NX&.tsrc=fin-srch
# ELA	|	1146	|	26.529x	|	18.40%	|	Entergy Louisiana, LLC First Mortgage Bonds, 5.875% Series due June 15, 2041 https://finance.yahoo.com/quote/ELA?p=ELA&.tsrc=fin-srch
# ZNH	|	1150	|	1.072x	|	6.45%	|	China Southern Airlines Company Limited Common Stock https://finance.yahoo.com/quote/ZNH?p=ZNH&.tsrc=fin-srch
# SMG	|	1150	|	26.500x	|	20.56%	|	Scotts Miracle https://finance.yahoo.com/quote/SMG?p=SMG&.tsrc=fin-srch
# TUP	|	1156	|	8.481x	|	53.00%	|	Tupperware Brands Corporation Common Stock https://finance.yahoo.com/quote/TUP?p=TUP&.tsrc=fin-srch
# OSK	|	1162	|	24.708x	|	9.88%	|	Oshkosh Corporation (Holding Company)Common Stock https://finance.yahoo.com/quote/OSK?p=OSK&.tsrc=fin-srch
# MCY	|	1164	|	9.635x	|	8.02%	|	Mercury General Corporation Common Stock https://finance.yahoo.com/quote/MCY?p=MCY&.tsrc=fin-srch
# HRL	|	1175	|	29.432x	|	12.90%	|	Hormel Foods Corporation Common Stock https://finance.yahoo.com/quote/HRL?p=HRL&.tsrc=fin-srch
# WLKP	|	1177	|	2.557x	|	25.95%	|	Westlake Chemical Partners LP Common Units representing limited partner interests https://finance.yahoo.com/quote/WLKP?p=WLKP&.tsrc=fin-srch
# KIM	|	1177	|	8.042x	|	8.25%	|	Kimco Realty Corporation Common Stock https://finance.yahoo.com/quote/KIM?p=KIM&.tsrc=fin-srch
# ASX	|	1181	|	0.557x	|	9.22%	|	Advanced Semiconductor Engineering, Inc. Common Stock https://finance.yahoo.com/quote/ASX?p=ASX&.tsrc=fin-srch
# WAT	|	1183	|	32.865x	|	30.02%	|	Waters Corporation Common Stock https://finance.yahoo.com/quote/WAT?p=WAT&.tsrc=fin-srch
# BIO	|	1187	|	4.829x	|	41.04%	|	Bio https://finance.yahoo.com/quote/BIO?p=BIO&.tsrc=fin-srch
# PBH	|	1188	|	13.902x	|	6.41%	|	Prestige Brand Holdings, Inc. Common Stock https://finance.yahoo.com/quote/PBH?p=PBH&.tsrc=fin-srch
# HPQ	|	1190	|	19.718x	|	34.32%	|	Hewlett https://finance.yahoo.com/quote/HPQ?p=HPQ&.tsrc=fin-srch
# SSD	|	1191	|	25.069x	|	24.03%	|	Simpson Manufacturing Company, Inc. Common Stock https://finance.yahoo.com/quote/SSD?p=SSD&.tsrc=fin-srch
# THQ	|	1191	|	10.989x	|	8.42%	|	Tekla Healthcare Opportunies Fund Shares of Beneficial Interest https://finance.yahoo.com/quote/THQ?p=THQ&.tsrc=fin-srch
# LLY	|	1194	|	31.690x	|	21.17%	|	Eli Lilly and Company Common Stock https://finance.yahoo.com/quote/LLY?p=LLY&.tsrc=fin-srch
# MAS	|	1194	|	8.222x	|	37.81%	|	Masco Corporation Common Stock https://finance.yahoo.com/quote/MAS?p=MAS&.tsrc=fin-srch
# IBP	|	1195	|	34.845x	|	13.79%	|	Installed Building Products, Inc. Common Stock https://finance.yahoo.com/quote/IBP?p=IBP&.tsrc=fin-srch
# MATX	|	1197	|	17.085x	|	10.84%	|	Matson, Inc. Common Stock https://finance.yahoo.com/quote/MATX?p=MATX&.tsrc=fin-srch
# AFC	|	1199	|	13.553x	|	10.71%	|	Allied Capital Corporation Allied Capital Corporation 6.875% Notes due April 15, 2047 https://finance.yahoo.com/quote/AFC?p=AFC&.tsrc=fin-srch
# STT	|	1202	|	11.878x	|	7.26%	|	State Street Corporation Common Stock https://finance.yahoo.com/quote/STT?p=STT&.tsrc=fin-srch
# TRI	|	1205	|	38.731x	|	10.74%	|	Thomson Reuters Corp Ordinary Shares https://finance.yahoo.com/quote/TRI?p=TRI&.tsrc=fin-srch
# MC	|	1207	|	17.837x	|	41.96%	|	Moelis & Company Class A Common Stock https://finance.yahoo.com/quote/MC?p=MC&.tsrc=fin-srch
# TMHC	|	1212	|	15.969x	|	7.05%	|	Taylor Morrison Home Corporation Class A Common Stock https://finance.yahoo.com/quote/TMHC?p=TMHC&.tsrc=fin-srch
# UNH	|	1215	|	13.003x	|	16.61%	|	UnitedHealth Group Incorporated Common Stock https://finance.yahoo.com/quote/UNH?p=UNH&.tsrc=fin-srch
# ETW	|	1219	|	2.635x	|	15.36%	|	Eaton Vance Corporation Eaton Vance Tax https://finance.yahoo.com/quote/ETW?p=ETW&.tsrc=fin-srch
# AWR	|	1229	|	30.527x	|	6.85%	|	American States Water Company Common Stock https://finance.yahoo.com/quote/AWR?p=AWR&.tsrc=fin-srch
# ANTM	|	1233	|	17.920x	|	7.20%	|	Anthem, Inc. Common Stock https://finance.yahoo.com/quote/ANTM?p=ANTM&.tsrc=fin-srch
# OPY	|	1234	|	4.372x	|	6.64%	|	Oppenheimer Holdings, Inc. Class A Common Stock (DE) https://finance.yahoo.com/quote/OPY?p=OPY&.tsrc=fin-srch
# ETN	|	1238	|	39.545x	|	6.73%	|	Eaton Corporation, PLC Ordinary Shares https://finance.yahoo.com/quote/ETN?p=ETN&.tsrc=fin-srch
# TPC	|	1247	|	6.563x	|	6.27%	|	Tutor Perini Corporation Common Stock https://finance.yahoo.com/quote/TPC?p=TPC&.tsrc=fin-srch
# DOV	|	1247	|	28.132x	|	11.63%	|	Dover Corporation Common Stock https://finance.yahoo.com/quote/DOV?p=DOV&.tsrc=fin-srch
# HIG	|	1250	|	10.778x	|	10.57%	|	Hartford Financial Services Group, Inc. (The) Common Stock https://finance.yahoo.com/quote/HIG?p=HIG&.tsrc=fin-srch
# AAP	|	1250	|	13.914x	|	24.90%	|	Advance Auto Parts Inc Advance Auto Parts Inc W/I https://finance.yahoo.com/quote/AAP?p=AAP&.tsrc=fin-srch
# MTOR	|	1264	|	9.452x	|	14.38%	|	Meritor, Inc. Common Stock https://finance.yahoo.com/quote/MTOR?p=MTOR&.tsrc=fin-srch
# CSL	|	1265	|	26.805x	|	7.69%	|	Carlisle Companies Incorporated Common Stock https://finance.yahoo.com/quote/CSL?p=CSL&.tsrc=fin-srch
# PAG	|	1266	|	12.397x	|	8.25%	|	Penske Automotive Group, Inc. Common Stock https://finance.yahoo.com/quote/PAG?p=PAG&.tsrc=fin-srch
# LOW	|	1267	|	27.619x	|	18.68%	|	Lowe's Companies, Inc. Common Stock https://finance.yahoo.com/quote/LOW?p=LOW&.tsrc=fin-srch
# TDY	|	1276	|	21.601x	|	18.45%	|	Teledyne Technologies Incorporated Common Stock https://finance.yahoo.com/quote/TDY?p=TDY&.tsrc=fin-srch
# RPM	|	1279	|	26.210x	|	12.27%	|	RPM International Inc. Common Stock https://finance.yahoo.com/quote/RPM?p=RPM&.tsrc=fin-srch
# HDB	|	1283	|	0.502x	|	9.39%	|	HDFC Bank Limited Common Stock https://finance.yahoo.com/quote/HDB?p=HDB&.tsrc=fin-srch
# PKI	|	1283	|	12.732x	|	21.24%	|	PerkinElmer, Inc. Common Stock https://finance.yahoo.com/quote/PKI?p=PKI&.tsrc=fin-srch
# DVA	|	1287	|	15.592x	|	9.08%	|	DaVita HealthCare Partners Inc. Common Stock https://finance.yahoo.com/quote/DVA?p=DVA&.tsrc=fin-srch
# MWA	|	1292	|	27.345x	|	8.18%	|	MUELLER WATER PRODUCTS Common Stock https://finance.yahoo.com/quote/MWA?p=MWA&.tsrc=fin-srch
# BST	|	1292	|	4.483x	|	31.35%	|	BlackRock Science and Technology Trust Common Shares of Beneficial Interest https://finance.yahoo.com/quote/BST?p=BST&.tsrc=fin-srch
# HCA	|	1294	|	16.772x	|	14.00%	|	HCA Holdings, Inc. Common Stock https://finance.yahoo.com/quote/HCA?p=HCA&.tsrc=fin-srch
# BIG	|	1306	|	3.892x	|	27.42%	|	Big Lots, Inc. Common Stock https://finance.yahoo.com/quote/BIG?p=BIG&.tsrc=fin-srch
# PDM	|	1306	|	9.909x	|	6.46%	|	Piedmont Office Realty Trust, Inc. Class A Common Stock https://finance.yahoo.com/quote/PDM?p=PDM&.tsrc=fin-srch
# MIXT	|	1321	|	25.989x	|	8.72%	|	MiX Telematics Limited American Depositary Shares, each representing 25 Ordinary Shares https://finance.yahoo.com/quote/MIXT?p=MIXT&.tsrc=fin-srch
# KR	|	1325	|	9.185x	|	11.75%	|	Kroger Company (The) Common Stock https://finance.yahoo.com/quote/KR?p=KR&.tsrc=fin-srch
# BXC	|	1327	|	2.598x	|	20.79%	|	Bluelinx Holdings Inc. Common Stock https://finance.yahoo.com/quote/BXC?p=BXC&.tsrc=fin-srch
# LII	|	1329	|	31.406x	|	33.44%	|	Lennox International, Inc. Common Stock https://finance.yahoo.com/quote/LII?p=LII&.tsrc=fin-srch
# EME	|	1330	|	46.515x	|	8.70%	|	EMCOR Group, Inc. Common Stock https://finance.yahoo.com/quote/EME?p=EME&.tsrc=fin-srch
# CTS	|	1331	|	30.900x	|	8.73%	|	CTS Corporation Common Stock https://finance.yahoo.com/quote/CTS?p=CTS&.tsrc=fin-srch
# NEM	|	1338	|	16.465x	|	8.27%	|	Newmont Mining Corporation https://finance.yahoo.com/quote/NEM?p=NEM&.tsrc=fin-srch
# VGR	|	1340	|	17.353x	|	17.99%	|	Vector Group Ltd. Common Stock https://finance.yahoo.com/quote/VGR?p=VGR&.tsrc=fin-srch
# TNET	|	1341	|	20.583x	|	30.43%	|	TriNet Group, Inc. Common Stock https://finance.yahoo.com/quote/TNET?p=TNET&.tsrc=fin-srch
# KNX	|	1342	|	18.079x	|	7.35%	|	Knight Transportation, Inc. Common Stock https://finance.yahoo.com/quote/KNX?p=KNX&.tsrc=fin-srch
# PH	|	1344	|	27.809x	|	10.93%	|	Parker https://finance.yahoo.com/quote/PH?p=PH&.tsrc=fin-srch
# INGR	|	1354	|	17.758x	|	9.37%	|	Ingredion Incorporated Common Stock https://finance.yahoo.com/quote/INGR?p=INGR&.tsrc=fin-srch
# KSU	|	1357	|	35.582x	|	8.25%	|	Kansas City Southern Common Stock https://finance.yahoo.com/quote/KSU?p=KSU&.tsrc=fin-srch
# CI	|	1368	|	10.283x	|	9.10%	|	Cigna Corporation Common Stock https://finance.yahoo.com/quote/CI?p=CI&.tsrc=fin-srch
# GBL	|	1379	|	9.513x	|	47.56%	|	Gamco Investors, Inc. Common Stock https://finance.yahoo.com/quote/GBL?p=GBL&.tsrc=fin-srch
# SNE	|	1383	|	0.106x	|	7.14%	|	Sony Corporation Common Stock https://finance.yahoo.com/quote/SNE?p=SNE&.tsrc=fin-srch
# V	|	1383	|	45.357x	|	19.94%	|	Visa Inc. https://finance.yahoo.com/quote/V?p=V&.tsrc=fin-srch
# EBS	|	1384	|	16.173x	|	16.30%	|	Emergent Biosolutions, Inc. Common Stock https://finance.yahoo.com/quote/EBS?p=EBS&.tsrc=fin-srch
# MCO	|	1385	|	30.798x	|	21.88%	|	Moody's Corporation Common Stock https://finance.yahoo.com/quote/MCO?p=MCO&.tsrc=fin-srch
# AVY	|	1390	|	16.349x	|	38.18%	|	Avery Dennison Corporation Common Stock https://finance.yahoo.com/quote/AVY?p=AVY&.tsrc=fin-srch
# DGX	|	1392	|	11.425x	|	15.38%	|	Quest Diagnostics Incorporated Common Stock https://finance.yahoo.com/quote/DGX?p=DGX&.tsrc=fin-srch
# OMC	|	1397	|	17.495x	|	11.63%	|	Omnicom Group Inc. Common Stock https://finance.yahoo.com/quote/OMC?p=OMC&.tsrc=fin-srch
# DKL	|	1401	|	8.425x	|	17.18%	|	Delek Logistics Partners, L.P. Common Units representing Limited Partner Interests https://finance.yahoo.com/quote/DKL?p=DKL&.tsrc=fin-srch
# HD	|	1407	|	28.195x	|	32.18%	|	Home Depot, Inc. (The) Common Stock https://finance.yahoo.com/quote/HD?p=HD&.tsrc=fin-srch
# AYI	|	1408	|	21.236x	|	11.76%	|	Acuity Brands Inc (Holding Company) https://finance.yahoo.com/quote/AYI?p=AYI&.tsrc=fin-srch
# MYI	|	1408	|	8.202x	|	7.27%	|	Blackrock MuniYield Quality Fund III, Inc Common Stock https://finance.yahoo.com/quote/MYI?p=MYI&.tsrc=fin-srch
# MMI	|	1413	|	31.345x	|	9.01%	|	Marcus & Millichap, Inc. Common Stock https://finance.yahoo.com/quote/MMI?p=MMI&.tsrc=fin-srch
# TCP	|	1413	|	10.281x	|	28.52%	|	TC PipeLines, LP Common Units representing Limited Partner Interests https://finance.yahoo.com/quote/TCP?p=TCP&.tsrc=fin-srch
# BKE	|	1416	|	17.740x	|	21.18%	|	Buckle, Inc. (The) Common Stock https://finance.yahoo.com/quote/BKE?p=BKE&.tsrc=fin-srch
# DFP	|	1441	|	12.382x	|	6.60%	|	Flaherty & Crumrine Dynamic Preferred and Income Fund Inc. Common Stock https://finance.yahoo.com/quote/DFP?p=DFP&.tsrc=fin-srch
# RHI	|	1451	|	28.241x	|	27.92%	|	Robert Half International Inc. Common Stock https://finance.yahoo.com/quote/RHI?p=RHI&.tsrc=fin-srch
# MMD	|	1455	|	12.907x	|	7.69%	|	MainStay DefinedTerm Municipal Opportunities Fund Common Shares of Beneficial Interest https://finance.yahoo.com/quote/MMD?p=MMD&.tsrc=fin-srch
# NNI	|	1456	|	8.430x	|	13.55%	|	Nelnet, Inc. Common Stock https://finance.yahoo.com/quote/NNI?p=NNI&.tsrc=fin-srch
# TSM	|	1460	|	1.190x	|	27.28%	|	Taiwan Semiconductor Manufacturing Company Ltd. https://finance.yahoo.com/quote/TSM?p=TSM&.tsrc=fin-srch
# CMI	|	1466	|	26.597x	|	12.13%	|	Cummins Inc. Common Stock https://finance.yahoo.com/quote/CMI?p=CMI&.tsrc=fin-srch
# MDU	|	1470	|	15.888x	|	6.70%	|	MDU Resources Group, Inc. Common Stock https://finance.yahoo.com/quote/MDU?p=MDU&.tsrc=fin-srch
# SBR	|	1475	|	11.680x	|	678.78%	|	Sabine Royalty Trust Common Stock https://finance.yahoo.com/quote/SBR?p=SBR&.tsrc=fin-srch
# HEP	|	1475	|	11.653x	|	8.59%	|	Holly Energy Partners, L.P. Common Stock https://finance.yahoo.com/quote/HEP?p=HEP&.tsrc=fin-srch
# MSCI	|	1482	|	56.706x	|	21.60%	|	MSCI Inc Common Stock https://finance.yahoo.com/quote/MSCI?p=MSCI&.tsrc=fin-srch
# LL	|	1484	|	12.012x	|	12.41%	|	Lumber Liquidators Holdings, Inc Common Stock https://finance.yahoo.com/quote/LL?p=LL&.tsrc=fin-srch
# APAM	|	1486	|	13.589x	|	61.00%	|	Artisan Partners Asset Management Inc. Class A Common Stock https://finance.yahoo.com/quote/APAM?p=APAM&.tsrc=fin-srch
# RXN	|	1488	|	38.832x	|	6.94%	|	Rexnord Corporation Common Stock https://finance.yahoo.com/quote/RXN?p=RXN&.tsrc=fin-srch
# CAT	|	1490	|	40.311x	|	7.59%	|	Caterpillar, Inc. Common Stock https://finance.yahoo.com/quote/CAT?p=CAT&.tsrc=fin-srch
# NLS	|	1493	|	9.629x	|	38.57%	|	Nautilus, Inc. Common Stock https://finance.yahoo.com/quote/NLS?p=NLS&.tsrc=fin-srch
# ETV	|	1497	|	3.966x	|	14.49%	|	Eaton Vance Corporation Eaton Vance Tax https://finance.yahoo.com/quote/ETV?p=ETV&.tsrc=fin-srch
# LPX	|	1498	|	11.196x	|	34.50%	|	Louisiana https://finance.yahoo.com/quote/LPX?p=LPX&.tsrc=fin-srch
# CTB	|	1500	|	20.353x	|	8.22%	|	Cooper Tire & Rubber Company Common Stock https://finance.yahoo.com/quote/CTB?p=CTB&.tsrc=fin-srch
# DHI	|	1500	|	15.462x	|	17.08%	|	D.R. Horton, Inc. Common Stock https://finance.yahoo.com/quote/DHI?p=DHI&.tsrc=fin-srch
# VMC	|	1504	|	38.979x	|	6.99%	|	Vulcan Materials Company (Holding Company) Common Stock https://finance.yahoo.com/quote/VMC?p=VMC&.tsrc=fin-srch
# VSH	|	1513	|	29.005x	|	6.11%	|	Vishay Intertechnology, Inc. Common Stock https://finance.yahoo.com/quote/VSH?p=VSH&.tsrc=fin-srch
# TNK	|	1517	|	2.224x	|	13.21%	|	Teekay Tankers Ltd. https://finance.yahoo.com/quote/TNK?p=TNK&.tsrc=fin-srch
# FSS	|	1520	|	24.136x	|	11.75%	|	Federal Signal Corporation Common Stock https://finance.yahoo.com/quote/FSS?p=FSS&.tsrc=fin-srch
# AGCO	|	1522	|	23.673x	|	10.93%	|	AGCO Corporation Common Stock https://finance.yahoo.com/quote/AGCO?p=AGCO&.tsrc=fin-srch
# KEYS	|	1536	|	40.181x	|	11.84%	|	Keysight Technologies Inc. Common Stock https://finance.yahoo.com/quote/KEYS?p=KEYS&.tsrc=fin-srch
# WHR	|	1542	|	12.066x	|	12.10%	|	Whirlpool Corporation Common Stock https://finance.yahoo.com/quote/WHR?p=WHR&.tsrc=fin-srch
# JNJ	|	1545	|	33.475x	|	10.52%	|	Johnson & Johnson Common Stock https://finance.yahoo.com/quote/JNJ?p=JNJ&.tsrc=fin-srch
# TFX	|	1549	|	57.922x	|	6.40%	|	Teleflex Incorporated Common Stock https://finance.yahoo.com/quote/TFX?p=TFX&.tsrc=fin-srch
# JBT	|	1551	|	42.106x	|	10.79%	|	John Bean Technologies Corporation Common Stock https://finance.yahoo.com/quote/JBT?p=JBT&.tsrc=fin-srch
# DLB	|	1561	|	17.410x	|	18.61%	|	Dolby Laboratories Common Stock https://finance.yahoo.com/quote/DLB?p=DLB&.tsrc=fin-srch
# USB	|	1561	|	15.407x	|	6.81%	|	U.S. Bancorp Common Stock https://finance.yahoo.com/quote/USB?p=USB&.tsrc=fin-srch
# EVTC	|	1562	|	25.654x	|	13.47%	|	Evertec, Inc. Common Stock https://finance.yahoo.com/quote/EVTC?p=EVTC&.tsrc=fin-srch
# LMT	|	1563	|	13.958x	|	22.39%	|	Lockheed Martin Corporation Common Stock https://finance.yahoo.com/quote/LMT?p=LMT&.tsrc=fin-srch
# FMX	|	1576	|	0.559x	|	10.96%	|	Fomento Economico Mexicano S.A.B. de C.V. Common Stock https://finance.yahoo.com/quote/FMX?p=FMX&.tsrc=fin-srch
# NPK	|	1581	|	16.460x	|	14.99%	|	National Presto Industries, Inc. Common Stock https://finance.yahoo.com/quote/NPK?p=NPK&.tsrc=fin-srch
# CCS	|	1584	|	10.376x	|	11.43%	|	Century Communities, Inc. Common Stock https://finance.yahoo.com/quote/CCS?p=CCS&.tsrc=fin-srch
# MTX	|	1586	|	16.451x	|	6.92%	|	Minerals Technologies Inc. Common Stock https://finance.yahoo.com/quote/MTX?p=MTX&.tsrc=fin-srch
# VMW	|	1586	|	38.584x	|	8.38%	|	Vmware, Inc. Common stock, Class A https://finance.yahoo.com/quote/VMW?p=VMW&.tsrc=fin-srch
# CW	|	1594	|	25.121x	|	8.19%	|	Curtiss https://finance.yahoo.com/quote/CW?p=CW&.tsrc=fin-srch
# USNA	|	1597	|	7.280x	|	74.26%	|	USANA Health Sciences, Inc. Common Stock https://finance.yahoo.com/quote/USNA?p=USNA&.tsrc=fin-srch
# FBHS	|	1605	|	22.397x	|	12.15%	|	Fortune Brands Home & Security, Inc. Common Stock https://finance.yahoo.com/quote/FBHS?p=FBHS&.tsrc=fin-srch
# ACI	|	1613	|	5.174x	|	12.78%	|	Arch Coal, Inc. Common Stock https://finance.yahoo.com/quote/ACI?p=ACI&.tsrc=fin-srch
# UZA	|	1616	|	1.435x	|	63.03%	|	United States Cellular Corporation 6.95% Senior Notes due 2060 https://finance.yahoo.com/quote/UZA?p=UZA&.tsrc=fin-srch
# AME	|	1628	|	32.555x	|	11.66%	|	AMETEK, Inc. https://finance.yahoo.com/quote/AME?p=AME&.tsrc=fin-srch
# GPI	|	1633	|	10.763x	|	11.41%	|	Group 1 Automotive, Inc. Common Stock https://finance.yahoo.com/quote/GPI?p=GPI&.tsrc=fin-srch
# SPG	|	1634	|	20.047x	|	6.57%	|	Simon Property Group, Inc. Common Stock https://finance.yahoo.com/quote/SPG?p=SPG&.tsrc=fin-srch
# ANET	|	1638	|	33.096x	|	18.61%	|	Arista Networks, Inc. Common Stock https://finance.yahoo.com/quote/ANET?p=ANET&.tsrc=fin-srch
# BTZ	|	1639	|	5.822x	|	17.49%	|	BlackRock Credit Allocation Income Trust https://finance.yahoo.com/quote/BTZ?p=BTZ&.tsrc=fin-srch
# WMS	|	1644	|	36.816x	|	13.47%	|	Advanced Drainage Systems, Inc. Common Stock https://finance.yahoo.com/quote/WMS?p=WMS&.tsrc=fin-srch
# VMI	|	1646	|	27.496x	|	8.46%	|	Valmont Industries, Inc. Common Stock https://finance.yahoo.com/quote/VMI?p=VMI&.tsrc=fin-srch
# PSA	|	1649	|	28.611x	|	12.28%	|	Public Storage Common Stock https://finance.yahoo.com/quote/PSA?p=PSA&.tsrc=fin-srch
# UMC	|	1651	|	0.848x	|	7.52%	|	United Microelectronics Corporation (NEW) Common Stock https://finance.yahoo.com/quote/UMC?p=UMC&.tsrc=fin-srch
# MFL	|	1659	|	5.969x	|	9.35%	|	Blackrock MuniHoldings Investment Quality Fund Common Shares of Beneficial Interest https://finance.yahoo.com/quote/MFL?p=MFL&.tsrc=fin-srch
# VEC	|	1662	|	18.960x	|	6.96%	|	Vectrus, Inc. Common Stock https://finance.yahoo.com/quote/VEC?p=VEC&.tsrc=fin-srch
# GIB	|	1666	|	17.534x	|	13.93%	|	CGI Group, Inc. Common Stock https://finance.yahoo.com/quote/GIB?p=GIB&.tsrc=fin-srch
# TR	|	1669	|	38.396x	|	8.34%	|	Tootsie Roll Industries, Inc. Common Stock https://finance.yahoo.com/quote/TR?p=TR&.tsrc=fin-srch
# SWM	|	1696	|	18.229x	|	6.84%	|	Schweitzer https://finance.yahoo.com/quote/SWM?p=SWM&.tsrc=fin-srch
# CNS	|	1697	|	42.032x	|	28.51%	|	Cohn & Steers Inc Common Stock https://finance.yahoo.com/quote/CNS?p=CNS&.tsrc=fin-srch
# NVR	|	1697	|	19.462x	|	21.85%	|	NVR, Inc. Common Stock https://finance.yahoo.com/quote/NVR?p=NVR&.tsrc=fin-srch
# FN	|	1697	|	26.982x	|	11.69%	|	Fabrinet Ordinary Shares https://finance.yahoo.com/quote/FN?p=FN&.tsrc=fin-srch
# MTZ	|	1702	|	21.633x	|	11.15%	|	MasTec, Inc. Common Stock https://finance.yahoo.com/quote/MTZ?p=MTZ&.tsrc=fin-srch
# UNF	|	1705	|	36.320x	|	8.50%	|	Unifirst Corporation Common Stock https://finance.yahoo.com/quote/UNF?p=UNF&.tsrc=fin-srch
# CLGX	|	1706	|	20.030x	|	9.26%	|	CoreLogic, Inc. Common Stock https://finance.yahoo.com/quote/CLGX?p=CLGX&.tsrc=fin-srch
# PHM	|	1718	|	9.288x	|	16.90%	|	PulteGroup, Inc. Common Stock https://finance.yahoo.com/quote/PHM?p=PHM&.tsrc=fin-srch
# LAD	|	1722	|	19.509x	|	11.96%	|	Lithia Motors, Inc. Common Stock https://finance.yahoo.com/quote/LAD?p=LAD&.tsrc=fin-srch
# FRO	|	1730	|	4.667x	|	9.60%	|	Frontline Ltd. Ordinary Shares https://finance.yahoo.com/quote/FRO?p=FRO&.tsrc=fin-srch
# RMD	|	1734	|	38.814x	|	20.78%	|	ResMed Inc. Common Stock https://finance.yahoo.com/quote/RMD?p=RMD&.tsrc=fin-srch
# SON	|	1738	|	30.108x	|	6.79%	|	Sonoco Products Company Common Stock https://finance.yahoo.com/quote/SON?p=SON&.tsrc=fin-srch
# MMS	|	1740	|	24.623x	|	19.38%	|	Maximus, Inc. Common Stock https://finance.yahoo.com/quote/MMS?p=MMS&.tsrc=fin-srch
# CNI	|	1748	|	22.989x	|	10.94%	|	Canadian National Railway Company Common Stock https://finance.yahoo.com/quote/CNI?p=CNI&.tsrc=fin-srch
# SNV	|	1752	|	17.009x	|	7.58%	|	Synovus Financial Corp. Common Stock https://finance.yahoo.com/quote/SNV?p=SNV&.tsrc=fin-srch
# TIF	|	1755	|	10.754x	|	6.50%	|	Tiffany & Co. Common Stock https://finance.yahoo.com/quote/TIF?p=TIF&.tsrc=fin-srch
# MMP	|	1756	|	12.398x	|	10.73%	|	Magellan Midstream Partners L.P. Limited Partnership https://finance.yahoo.com/quote/MMP?p=MMP&.tsrc=fin-srch
# HGH	|	1758	|	4.694x	|	3970.54%	|	Hartford Financial Services Group, Inc. (The) 7.875% Fixed to Floating Rate Junior Subordinated Debentures due 2042 https://finance.yahoo.com/quote/HGH?p=HGH&.tsrc=fin-srch
# CL	|	1768	|	23.867x	|	31.67%	|	Colgate https://finance.yahoo.com/quote/CL?p=CL&.tsrc=fin-srch
# SYX	|	1768	|	23.130x	|	30.61%	|	Systemax Inc. Common Stock https://finance.yahoo.com/quote/SYX?p=SYX&.tsrc=fin-srch
# FMC	|	1775	|	25.415x	|	9.92%	|	FMC Corporation Common Stock https://finance.yahoo.com/quote/FMC?p=FMC&.tsrc=fin-srch
# BWA	|	1782	|	23.597x	|	7.89%	|	BorgWarner Inc. Common Stock https://finance.yahoo.com/quote/BWA?p=BWA&.tsrc=fin-srch
# ITW	|	1784	|	32.030x	|	20.76%	|	Illinois Tool Works Inc. Common Stock https://finance.yahoo.com/quote/ITW?p=ITW&.tsrc=fin-srch
# HMLP	|	1787	|	9.289x	|	6.94%	|	Hoegh LNG Partners LP Common Units representing Limited Partner Interests https://finance.yahoo.com/quote/HMLP?p=HMLP&.tsrc=fin-srch
# HRC	|	1794	|	28.995x	|	8.00%	|	Hill https://finance.yahoo.com/quote/HRC?p=HRC&.tsrc=fin-srch
# THO	|	1801	|	29.627x	|	6724.99%	|	Thor Industries, Inc. Common Stock https://finance.yahoo.com/quote/THO?p=THO&.tsrc=fin-srch
# CHD	|	1803	|	25.773x	|	16.16%	|	Church & Dwight Company, Inc. Common Stock https://finance.yahoo.com/quote/CHD?p=CHD&.tsrc=fin-srch
# BDN	|	1809	|	7.693x	|	8.20%	|	Brandywine Realty Trust Common Stock https://finance.yahoo.com/quote/BDN?p=BDN&.tsrc=fin-srch
# CIEN	|	1810	|	23.277x	|	12.88%	|	Ciena Corporation Common Stock https://finance.yahoo.com/quote/CIEN?p=CIEN&.tsrc=fin-srch
# SC	|	1812	|	9.178x	|	16.76%	|	Santander Consumer USA Holdings Inc. Common Stock https://finance.yahoo.com/quote/SC?p=SC&.tsrc=fin-srch
# ICE	|	1814	|	30.212x	|	7.24%	|	Intercontinental Exchange Inc. Common Stock https://finance.yahoo.com/quote/ICE?p=ICE&.tsrc=fin-srch
# HRB	|	1815	|	11.931x	|	21361.18%	|	H&R Block, Inc. Common Stock https://finance.yahoo.com/quote/HRB?p=HRB&.tsrc=fin-srch
# HVT	|	1819	|	11.171x	|	16.08%	|	Haverty Furniture Companies, Inc. Common Stock https://finance.yahoo.com/quote/HVT?p=HVT&.tsrc=fin-srch
# WOR	|	1819	|	6.893x	|	29.76%	|	Worthington Industries, Inc. Common Stock https://finance.yahoo.com/quote/WOR?p=WOR&.tsrc=fin-srch
# TMO	|	1820	|	28.030x	|	12.30%	|	Thermo Fisher Scientific Inc Common Stock https://finance.yahoo.com/quote/TMO?p=TMO&.tsrc=fin-srch
# ROK	|	1825	|	23.578x	|	25.11%	|	Rockwell Automation, Inc. Common Stock https://finance.yahoo.com/quote/ROK?p=ROK&.tsrc=fin-srch
# WTS	|	1827	|	35.466x	|	11.71%	|	Watts Water Technologies, Inc. Class A Common Stock https://finance.yahoo.com/quote/WTS?p=WTS&.tsrc=fin-srch
# FAF	|	1851	|	9.185x	|	7.88%	|	First American Corporation (New) Common Stock https://finance.yahoo.com/quote/FAF?p=FAF&.tsrc=fin-srch
# HUM	|	1852	|	15.949x	|	21.32%	|	Humana Inc. Common Stock https://finance.yahoo.com/quote/HUM?p=HUM&.tsrc=fin-srch
# DPZ	|	1870	|	17.215x	|	83.98%	|	Domino's Pizza Inc Common Stock https://finance.yahoo.com/quote/DPZ?p=DPZ&.tsrc=fin-srch
# DNP	|	1874	|	9.414x	|	8.94%	|	DNP Select Income Fund, Inc. Common Stock https://finance.yahoo.com/quote/DNP?p=DNP&.tsrc=fin-srch
# SRLP	|	1876	|	13.200x	|	7.85%	|	Sprague Resources LP Common Units representing Limited Partner Interests https://finance.yahoo.com/quote/SRLP?p=SRLP&.tsrc=fin-srch
# VZ	|	1881	|	12.633x	|	8.66%	|	Verizon Communications Inc. Common Stock https://finance.yahoo.com/quote/VZ?p=VZ&.tsrc=fin-srch
# ACN	|	1883	|	31.059x	|	27.35%	|	Accenture plc. Class A Ordinary Shares (Ireland) https://finance.yahoo.com/quote/ACN?p=ACN&.tsrc=fin-srch
# AB	|	1884	|	13.325x	|	19.20%	|	Allianceberstein Holding L.P.  Units https://finance.yahoo.com/quote/AB?p=AB&.tsrc=fin-srch
# EV	|	1907	|	57.596x	|	7.38%	|	Eaton Vance Corporation Common Stock https://finance.yahoo.com/quote/EV?p=EV&.tsrc=fin-srch
# ZTS	|	1909	|	44.449x	|	17.45%	|	Zoetis Inc. Class A Common Stock https://finance.yahoo.com/quote/ZTS?p=ZTS&.tsrc=fin-srch
# FICO	|	1912	|	50.696x	|	25.56%	|	Fair Isaac Corproation Common Stock https://finance.yahoo.com/quote/FICO?p=FICO&.tsrc=fin-srch
# WGO	|	1912	|	26.663x	|	9.15%	|	Winnebago Industries, Inc. Common Stock https://finance.yahoo.com/quote/WGO?p=WGO&.tsrc=fin-srch
# SCL	|	1916	|	23.306x	|	12.81%	|	Stepan Company Common Stock https://finance.yahoo.com/quote/SCL?p=SCL&.tsrc=fin-srch
# WU	|	1920	|	13.596x	|	9.50%	|	Western Union Company (The) Common Stock https://finance.yahoo.com/quote/WU?p=WU&.tsrc=fin-srch
# NID	|	1935	|	15.386x	|	6.53%	|	Nuveen Intermediate Duration Municipal Term Fund Common Shares of Beneficial Interest https://finance.yahoo.com/quote/NID?p=NID&.tsrc=fin-srch
# SPB	|	1937	|	18.003x	|	6.74%	|	Spectrum Brands Holdings, Inc. Common Stock https://finance.yahoo.com/quote/SPB?p=SPB&.tsrc=fin-srch
# TPH	|	1947	|	9.467x	|	9.07%	|	Tri Pointe Homes, Inc. Common Stock https://finance.yahoo.com/quote/TPH?p=TPH&.tsrc=fin-srch
# CEA	|	1948	|	0.860x	|	6.87%	|	China Eastern Airlines Corporation Ltd. Common Stock https://finance.yahoo.com/quote/CEA?p=CEA&.tsrc=fin-srch
# MED	|	1951	|	28.856x	|	81.50%	|	MEDIFAST INC Common Stock https://finance.yahoo.com/quote/MED?p=MED&.tsrc=fin-srch
# WY	|	1956	|	27.416x	|	6.39%	|	Weyerhaeuser Company Common Stock https://finance.yahoo.com/quote/WY?p=WY&.tsrc=fin-srch
# SMP	|	1957	|	17.122x	|	16.42%	|	Standard Motor Products, Inc. Common Stock https://finance.yahoo.com/quote/SMP?p=SMP&.tsrc=fin-srch
# PBFX	|	1973	|	5.708x	|	16.57%	|	PBF Logistics LP Common Units representing limited partner interests https://finance.yahoo.com/quote/PBFX?p=PBFX&.tsrc=fin-srch
# HON	|	1978	|	31.327x	|	13.25%	|	Honeywell International Inc. Common Stock https://finance.yahoo.com/quote/HON?p=HON&.tsrc=fin-srch
# MPX	|	1990	|	32.194x	|	25.02%	|	Marine Products Corporation Common Stock https://finance.yahoo.com/quote/MPX?p=MPX&.tsrc=fin-srch
# AIN	|	1992	|	28.867x	|	10.23%	|	Albany International Corporation Common Stock https://finance.yahoo.com/quote/AIN?p=AIN&.tsrc=fin-srch
# PKG	|	2014	|	29.011x	|	9.51%	|	Packaging Corporation of America Common Stock https://finance.yahoo.com/quote/PKG?p=PKG&.tsrc=fin-srch
# WMK	|	2018	|	13.179x	|	10.98%	|	Weis Markets, Inc. Common Stock https://finance.yahoo.com/quote/WMK?p=WMK&.tsrc=fin-srch
# KO	|	2019	|	28.328x	|	13.41%	|	Coca https://finance.yahoo.com/quote/KO?p=KO&.tsrc=fin-srch
# LNN	|	2022	|	48.504x	|	9.41%	|	Lindsay Corporation Common Stock https://finance.yahoo.com/quote/LNN?p=LNN&.tsrc=fin-srch
# USPH	|	2025	|	29.404x	|	13.08%	|	U.S. Physical Therapy, Inc. Common Stock https://finance.yahoo.com/quote/USPH?p=USPH&.tsrc=fin-srch
# GD	|	2041	|	21.202x	|	7.82%	|	General Dynamics Corporation Common Stock https://finance.yahoo.com/quote/GD?p=GD&.tsrc=fin-srch
# ALG	|	2045	|	32.424x	|	7.77%	|	Alamo Group, Inc. Common Stock https://finance.yahoo.com/quote/ALG?p=ALG&.tsrc=fin-srch
# GWW	|	2046	|	30.079x	|	19.51%	|	W.W. Grainger, Inc. Common Stock https://finance.yahoo.com/quote/GWW?p=GWW&.tsrc=fin-srch
# EVR	|	2046	|	15.647x	|	23.44%	|	Evercore Partners Inc Class A Common Stock https://finance.yahoo.com/quote/EVR?p=EVR&.tsrc=fin-srch
# G	|	2049	|	26.256x	|	10.91%	|	Genpact Limited Common Stock https://finance.yahoo.com/quote/G?p=G&.tsrc=fin-srch
# UNM	|	2061	|	6.150x	|	8.72%	|	Unum Group Common Stock https://finance.yahoo.com/quote/UNM?p=UNM&.tsrc=fin-srch
# VMO	|	2073	|	6.593x	|	8.78%	|	Invesco Municipal Opportunity Trust Common Stock https://finance.yahoo.com/quote/VMO?p=VMO&.tsrc=fin-srch
# SCHW	|	2078	|	25.943x	|	10.89%	|	Charles Schwab Corporation (The) Common Stock https://finance.yahoo.com/quote/SCHW?p=SCHW&.tsrc=fin-srch
# UGI	|	2090	|	13.602x	|	6.26%	|	UGI Corporation Common Stock https://finance.yahoo.com/quote/UGI?p=UGI&.tsrc=fin-srch
# MRK	|	2145	|	26.831x	|	13.68%	|	Merck & Company, Inc. Common Stock (new) https://finance.yahoo.com/quote/MRK?p=MRK&.tsrc=fin-srch
# PGR	|	2151	|	9.453x	|	13.61%	|	Progressive Corporation (The) Common Stock https://finance.yahoo.com/quote/PGR?p=PGR&.tsrc=fin-srch
# DE	|	2154	|	32.873x	|	9.16%	|	Deere & Company Common Stock https://finance.yahoo.com/quote/DE?p=DE&.tsrc=fin-srch
# FCN	|	2171	|	20.550x	|	12.45%	|	FTI Consulting, Inc. Common Stock https://finance.yahoo.com/quote/FCN?p=FCN&.tsrc=fin-srch
# YUM	|	2185	|	35.157x	|	24.42%	|	Yum! Brands, Inc. https://finance.yahoo.com/quote/YUM?p=YUM&.tsrc=fin-srch
# PMX	|	2204	|	8.014x	|	8.01%	|	PIMCO Municipal Income Fund III Common Shares of Beneficial Interest https://finance.yahoo.com/quote/PMX?p=PMX&.tsrc=fin-srch
# CBZ	|	2250	|	22.980x	|	9.11%	|	CBIZ, Inc. Common Stock https://finance.yahoo.com/quote/CBZ?p=CBZ&.tsrc=fin-srch
# ABG	|	2266	|	14.073x	|	13.78%	|	Asbury Automotive Group Inc Common Stock https://finance.yahoo.com/quote/ABG?p=ABG&.tsrc=fin-srch
# AJG	|	2274	|	29.357x	|	7.14%	|	Arthur J. Gallagher & Co. Common Stock https://finance.yahoo.com/quote/AJG?p=AJG&.tsrc=fin-srch
# ATEN	|	2285	|	44.484x	|	10.46%	|	A10 Networks, Inc. Common Stock https://finance.yahoo.com/quote/ATEN?p=ATEN&.tsrc=fin-srch
# DY	|	2297	|	28.017x	|	11.63%	|	Dycom Industries, Inc. Common Stock https://finance.yahoo.com/quote/DY?p=DY&.tsrc=fin-srch
# AON	|	2297	|	16.733x	|	26.84%	|	Aon plc Class A Ordinary Shares (UK) https://finance.yahoo.com/quote/AON?p=AON&.tsrc=fin-srch
# PM	|	2327	|	15.709x	|	43.46%	|	Philip Morris International Inc Common Stock https://finance.yahoo.com/quote/PM?p=PM&.tsrc=fin-srch
# BERY	|	2332	|	9.969x	|	7.18%	|	Berry Plastics Group, Inc. Common Stock https://finance.yahoo.com/quote/BERY?p=BERY&.tsrc=fin-srch
# AOS	|	2397	|	30.695x	|	19.52%	|	A.O. Smith Corporation Common Stock https://finance.yahoo.com/quote/AOS?p=AOS&.tsrc=fin-srch

# %% [markdown]
# ## Generate & export a .csv file for further analysis

# %%
with open('value_stock_analysis.csv', mode='w', newline='') as csv_file:
    fieldnames = ['name', 'pe', 'roic', 'pe_rank', 'roic_rank', 'rank', 'Full Name', 'Website']
    writer = csv.DictWriter(csv_file, fieldnames=fieldnames)
    
    writer.writeheader()
    for row in stockdat:
        writer.writerow(row)
